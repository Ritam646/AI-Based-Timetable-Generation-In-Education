# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import re
import os

# Define file paths for Kaggle input directory
dataset_dir = '/kaggle/input/syllabus-data-new/'
cse_file = os.path.join(dataset_dir, 'CSE_Syllabus_Complete.xlsx')
ece_file = os.path.join(dataset_dir, 'ECE_Syllabus_Final.xlsx')
it_file = os.path.join(dataset_dir, 'IT_Complete_Syllabus.xlsx')

# Function to load and parse dataframe from xlsx file
def load_df(file_path, dept):
    df = pd.read_excel(file_path)
    df['Department'] = dept
    df['Semester'] = pd.to_numeric(df['Semester'], errors='coerce')
    df = df.dropna(subset=['Semester'])
    return df

# Load the three files
cse_df = load_df(cse_file, 'CSE')
ece_df = load_df(ece_file, 'ECE')
it_df = load_df(it_file, 'IT')

# Combine all dataframes
all_df = pd.concat([cse_df, ece_df, it_df], ignore_index=True)

# Parse data into dictionary
def parse_data(df):
    data = {}
    for _, row in df.iterrows():
        sem = int(row['Semester'])
        if 'Subject (with Paper Code)' in df.columns and pd.notna(row.get('Subject (with Paper Code)', None)):
            subject = row['Subject (with Paper Code)']
        elif 'Subject' in df.columns and pd.notna(row.get('Subject', None)):
            subject = row['Subject']
        else:
            continue
        dept = row['Department']
        if pd.isna(subject):
            continue
        subject = re.sub(r'\s+', ' ', str(subject)).strip()
        if not subject:
            continue
        if dept not in data:
            data[dept] = {}
        if sem not in data[dept]:
            data[dept][sem] = []
        if subject not in data[dept][sem]:
            data[dept][sem].append(subject)
    return data

# Build the data dictionary
all_data = parse_data(all_df)

# Function to get subjects
def get_subjects(department, semester):
    dept = department.upper()
    try:
        semester = int(semester)
        if dept in all_data and semester in all_data[dept]:
            return all_data[dept][semester]
        return []
    except ValueError:
        return []

# %%
# Test query
query = "IT 1"  # Example query, modify as needed (e.g., "ECE 3", "IT 5")
query_results = []
try:
    dept, sem = query.split(maxsplit=1)
    query_results = get_subjects(dept, sem)
except ValueError:
    print("Invalid query format. Use format: 'department semester' (e.g., 'CSE 5')")

# Output results
print("Query:", query)
print("Retrieved Subjects:", query_results)
# Out:
# Query: IT 1
# Retrieved Subjects: ['BS- - Mathematics –IA', 'BS-PH101 - Physics-I', 'ES-EE101 - Basic Electrical Engineering', 'BS-PH191 - Physics-I Laboratory', 'ES-EE191 - Basic Electrical Engineering Lab', 'ES-ME192 - Workshop']

# %%
# Test query
query = "CSE 4"  # Example query, modify as needed (e.g., "ECE 3", "IT 5")
query_results = []
try:
    dept, sem = query.split(maxsplit=1)
    query_results = get_subjects(dept, sem)
except ValueError:
    print("Invalid query format. Use format: 'department semester' (e.g., 'CSE 5')")
    query_results = []

# Output results with improved formatting
print(f"\nQuery: {query}")
print("\nRetrieved Subjects (Individual):")
if query_results:
    for i, subject in enumerate(query_results, 1):
        print(f"{i}. {subject}")
else:
    print("No subjects found for the given department and semester.")
print("\nRetrieved Subjects (List Format):")
print(query_results)
# Out:
# Query: CSE 4
#
# Retrieved Subjects (Individual):
# 1. Biology (BSC)
# 2. Computer Architecture (PCC-CS402)
# 3. Computer Architecture Lab (PCC-CS492)
# 4. Design &Analysis Algorithm Lab (PCC-CS494)
# 5. Design and Analysis ofAlgorithms (PCC-CS404)
# 6. Discrete Mathematics (PCC-CS401)
# 7. Environmental Sciences (MC-401)
# 8. Formal Language & Automata Theory (PCC-CS403)
#
# Retrieved Subjects (List Format):
# ['Biology (BSC)', 'Computer Architecture (PCC-CS402)', 'Computer Architecture Lab (PCC-CS492)', 'Design &Analysis Algorithm Lab (PCC-CS494)', 'Design and Analysis ofAlgorithms (PCC-CS404)', 'Discrete Mathematics (PCC-CS401)', 'Environmental Sciences (MC-401)', 'Formal Language & Automata Theory (PCC-CS403)']

# %% [markdown]
# rag implementation

# %%
# !pip install --no-deps PyPDF2 python-docx langchain langchain-community langchain-huggingface groq sentence-transformers pymupdf
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.26)
# Collecting langchain-community
#   Downloading langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.3.1-py3-none-any.whl.metadata (996 bytes)
# Collecting groq
#   Downloading groq-0.31.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Collecting pymupdf
#   Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 8.4 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 14.0 MB/s eta 0:00:00
# Downloading langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 62.9 MB/s eta 0:00:00:00:01
# Downloading langchain_huggingface-0.3.1-py3-none-any.whl (27 kB)
# Downloading groq-0.31.1-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 8.1 MB/s eta 0:00:00
# Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 64.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: python-docx, PyPDF2, pymupdf, langchain-huggingface, langchain-community, groq
# Successfully installed PyPDF2-3.0.1 groq-0.31.1 langchain-community-0.3.29 langchain-huggingface-0.3.1 pymupdf-1.26.4 python-docx-1.2.0

# %%
# !pip install langchain-groq
# !pip install docx2txt
# !pip install faiss-gpu
# !pip install faiss-cpu
# !pip install supabase
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.8-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-core<1.0.0,>=0.3.75 (from langchain-groq)
#   Downloading langchain_core-0.3.76-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: groq<1,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from langchain-groq) (0.31.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.14.0)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (0.4.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.75->langchain-groq) (25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain-groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain-groq) (2.5.0)
# Downloading langchain_groq-0.3.8-py3-none-any.whl (16 kB)
# Downloading langchain_core-0.3.76-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 14.8 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langchain-groq
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.66
#     Uninstalling langchain-core-0.3.66:
#       Successfully uninstalled langchain-core-0.3.66
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.3.29 requires httpx-sse<1.0.0,>=0.4.0, which is not installed.
# langchain-community 0.3.29 requires pydantic-settings<3.0.0,>=2.10.1, which is not installed.
# langchain-huggingface 0.3.1 requires huggingface-hub>=0.33.4, but you have huggingface-hub 0.33.1 which is incompatible.
# langchain-community 0.3.29 requires langchain<2.0.0,>=0.3.27, but you have langchain 0.3.26 which is incompatible.
# langchain-community 0.3.29 requires requests<3,>=2.32.5, but you have requests 2.32.4 which is incompatible.
# Successfully installed langchain-core-0.3.76 langchain-groq-0.3.8
# Collecting docx2txt
#   Downloading docx2txt-0.9-py3-none-any.whl.metadata (529 bytes)
# Downloading docx2txt-0.9-py3-none-any.whl (4.0 kB)
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.9
# ERROR: Could not find a version that satisfies the requirement faiss-gpu (from versions: none)
# ERROR: No matching distribution found for faiss-gpu
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 51.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0
# Collecting supabase
#   Downloading supabase-2.19.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting realtime (from supabase)
#   Downloading realtime-2.19.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting supabase-functions (from supabase)
#   Downloading supabase_functions-2.19.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting storage3 (from supabase)
#   Downloading storage3-2.19.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting supabase-auth (from supabase)
#   Downloading supabase_auth-2.19.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting postgrest (from supabase)
#   Downloading postgrest-2.19.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in /usr/local/lib/python3.11/dist-packages (from supabase) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.26->supabase) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.26->supabase) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.26->supabase) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Collecting deprecation>=2.1.0 (from postgrest->supabase)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pydantic<3.0,>=1.9 in /usr/local/lib/python3.11/dist-packages (from postgrest->supabase) (2.11.7)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.11/dist-packages (from realtime->supabase) (4.14.0)
# Requirement already satisfied: websockets<16,>=11 in /usr/local/lib/python3.11/dist-packages (from realtime->supabase) (15.0.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.10.1->supabase-auth->supabase) (2.10.1)
# Collecting strenum>=0.4.15 (from supabase-functions->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from deprecation>=2.1.0->postgrest->supabase) (25.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.11/dist-packages (from httpx[http2]<0.29,>=0.26->postgrest->supabase) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0,>=1.9->postgrest->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0,>=1.9->postgrest->supabase) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0,>=1.9->postgrest->supabase) (0.4.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.10.1->supabase-auth->supabase) (44.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<0.29,>=0.26->supabase) (1.3.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth->supabase) (1.17.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest->supabase) (4.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth->supabase) (2.22)
# Downloading supabase-2.19.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.19.0-py3-none-any.whl (21 kB)
# Downloading realtime-2.19.0-py3-none-any.whl (21 kB)
# Downloading storage3-2.19.0-py3-none-any.whl (18 kB)
# Downloading supabase_auth-2.19.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 2.8 MB/s eta 0:00:00
# Downloading supabase_functions-2.19.0-py3-none-any.whl (8.3 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Installing collected packages: strenum, deprecation, realtime, supabase-functions, supabase-auth, storage3, postgrest, supabase
# Successfully installed deprecation-2.1.0 postgrest-2.19.0 realtime-2.19.0 storage3-2.19.0 strenum-0.4.15 supabase-2.19.0 supabase-auth-2.19.0 supabase-functions-2.19.0

# %%
import os
import PyPDF2
import docx
import pandas as pd
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import SupabaseVectorStore
from langchain.schema import Document
from groq import Groq
from supabase import create_client, Client
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
import os
import traceback
import fitz
import pandas as pd
from pathlib import Path

# %%
# Initialize Supabase client
SUPABASE_URL = "https://huvilonasynwyqycxyyf.supabase.co"
SUPABASE_KEY = "REDACTED_SUPABASE_KEY"
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# %%
# Initialize Groq client
os.environ["GROQ_API_KEY"] = "REDACTED_GROQ_KEY"
client = Groq()

# %%
from langchain_community.document_loaders import (
    PyPDFLoader, TextLoader, CSVLoader, Docx2txtLoader
)
from langchain_core.documents import Document

from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_groq import ChatGroq
from langchain.chains import RetrievalQA

# %%
# ================== ROBUST LOADERS ==================
class RobustPDFLoader(PyPDFLoader):
    """Try PyMuPDF first, then fall back to PyPDFLoader."""
    def load(self):
        try:
            doc = fitz.open(self.file_path)
            pages = []
            for i, page in enumerate(doc):
                text = page.get_text("text") or ""
                if text.strip():
                    pages.append(Document(
                        page_content=text,
                        metadata={
                            "source": str(self.file_path),
                            "page": i+1,
                            "loader": "pymupdf"
                        }
                    ))
            doc.close()
            if pages:
                return pages
        except Exception as e:
            print(f"[PDF] PyMuPDF failed for {self.file_path}: {e}\n{traceback.format_exc()}")
        try:
            return super().load()
        except Exception as e:
            print(f"[PDF] PyPDFLoader failed for {self.file_path}: {e}\n{traceback.format_exc()}")
            return []


def load_excel_to_documents(file_path: str) -> list[Document]:
    docs = []
    try:
        xls = pd.ExcelFile(file_path)
        for sheet_name in xls.sheet_names:
            df = xls.parse(sheet_name)
            text = df.to_csv(index=False)
            if text.strip():
                docs.append(Document(
                    page_content=text,
                    metadata={
                        "source": str(file_path),
                        "sheet": sheet_name,
                        "loader": "pandas_excel"
                    }
                ))
    except Exception as e:
        print(f"[EXCEL] Failed {file_path}: {e}\n{traceback.format_exc()}")
    return docs


def load_file_to_documents(file_path: str) -> list[Document]:
    """Load a single file into Documents depending on type."""
    ext = Path(file_path).suffix.lower()
    try:
        if ext == ".pdf":
            return RobustPDFLoader(file_path).load()
        elif ext in [".txt", ".md", ".log"]:
            return TextLoader(file_path, autodetect_encoding=True).load()
        elif ext == ".csv":
            return CSVLoader(file_path).load()
        elif ext in [".xls", ".xlsx"]:
            return load_excel_to_documents(file_path)
        elif ext == ".docx":
            return Docx2txtLoader(file_path).load()
        else:
            print(f"[SKIP] Unsupported file type: {file_path}")
            return []
    except Exception as e:
        print(f"[LOAD ERR] {file_path}: {e}\n{traceback.format_exc()}")
        return []

def gather_documents_recursive(root_dir: str, allowed_ext=None) -> list[Document]:
    """Walk directory recursively, load all supported files into Documents."""
    if allowed_ext is None:
        allowed_ext = {".pdf", ".txt", ".csv", ".xls", ".xlsx", ".docx"}
    all_docs = []
    for dirpath, _, filenames in os.walk(root_dir):
        for name in filenames:
            ext = Path(name).suffix.lower()
            if ext in allowed_ext:
                fpath = os.path.join(dirpath, name)
                docs = load_file_to_documents(fpath)
                for d in docs:
                    d.metadata.setdefault("source", fpath)
                    d.metadata["relpath"] = os.path.relpath(fpath, root_dir)
                    d.metadata["subfolder"] = os.path.relpath(dirpath, root_dir)
                all_docs.extend(docs)
    return all_docs
# ================== RAG PIPELINE ==================
def build_vectorstore(root_dir: str, embeddings_model="sentence-transformers/all-MiniLM-L6-v2"):
    print(f"[INFO] Loading documents from {root_dir} ...")
    docs = gather_documents_recursive(root_dir)

    print(f"[INFO] Loaded {len(docs)} raw documents. Splitting ...")
    splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    chunks = splitter.split_documents(docs)

    print(f"[INFO] Split into {len(chunks)} chunks. Building FAISS index ...")
    embeddings = HuggingFaceEmbeddings(model_name=embeddings_model)
    vectorstore = FAISS.from_documents(chunks, embeddings)

    return vectorstore


def build_rag_chain(vectorstore, groq_api_key: str, model="llama-3.3-70b-versatile"):
    llm = ChatGroq(api_key=groq_api_key, model=model)
    retriever = vectorstore.as_retriever(search_kwargs={"k": 5})
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        retriever=retriever,
        chain_type="stuff",
        return_source_documents=True
    )
    return qa_chain


def rag_query(qa_chain, query: str):
    result = qa_chain.invoke({"query": query})
    print("\n=== ANSWER ===")
    print(result["result"])

    print("\n=== SOURCES ===")
    for doc in result["source_documents"]:
        print(f"- {doc.metadata.get('relpath', doc.metadata.get('source'))}")
    return result


# ================== USAGE EXAMPLE ==================
# ================== USAGE EXAMPLE ==================
if __name__ == "__main__":
    DATA_DIR = "/kaggle/input/full-final-rag-nep/MAKAUT_Syllabus"   # <-- adjust path in Kaggle
    GROQ_API_KEY = "REDACTED_GROQ_KEY"                # <-- don't hardcode, use Kaggle secrets if possible

    # Build Vectorstore
    vs = build_vectorstore(DATA_DIR)

    # Create RAG Chain
    rag_chain = build_rag_chain(vs, GROQ_API_KEY)

    # Query Example
    rag_query(rag_chain, "Operating Systm in taught in which Semester")
# Out:
# [INFO] Loading documents from /kaggle/input/full-final-rag-nep/MAKAUT_Syllabus ...
# [INFO] Loaded 212 raw documents. Splitting ...
# [INFO] Split into 697 chunks. Building FAISS index ...
# 2025-09-17 22:37:49.384672: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758148669.588678      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758148669.649152      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# === ANSWER ===
# The provided context does not explicitly mention the semester in which the Operating System course is taught. It only provides the syllabus and course outcomes for the Operating System course (PCC-CS502) for B. Tech in Information Technology, but does not specify the semester.
#
# === SOURCES ===
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
# - CSE/AllSem23.pdf
# - CSE/AllSem23.pdf
# - CSE/AllSem23.pdf

# %%
# Initialize an empty dictionary to store subject and contact hours
contact_hours_dict = {}

# Function to extract contact hours from the response string
def extract_contact_hours(response):
    if not response or "don't know" in response.lower():
        return None  # Return None for unknown hours
    # Extract the part like "2L+1T" or "3L/week" from the response
    import re
    match = re.search(r'(\d+[LPT](?:\+?\d*[LPT]?)?(?:/week)?)', response)
    return match.group(0) if match else None

# Iterate over the query_results list
for subject in query_results:
    # Construct the query for contact hours
    query = f"Contact hours/week of {subject}"
    # Call the rag_query function (assuming it returns a dictionary with 'result')
    response = rag_query(rag_chain, query)
    # Extract the contact hours string
    contact_hours = extract_contact_hours(response.get('result', '') if isinstance(response, dict) else response)
    # Store the result in the dictionary (use None or a default if not found)
    contact_hours_dict[subject] = contact_hours if contact_hours else "Unknown"

# Output the resulting dictionary
print(contact_hours_dict)
# Out:
# === ANSWER ===
# The contact hours/week for the Biology course (BSC 401) is 2L+1T, which translates to 2 lectures and 1 tutorial per week, but I don't know the specific contact hours for a general Biology course, this one is for Chemistry and other courses titled as BSC 401, which is actually Chemistry-I.
#
# === SOURCES ===
# - CSE/AllSem23.pdf
# - CSE/AllSem23.pdf
# - CSE/AllSem23.pdf
# - CSE/AllSem23.pdf
# - IT/AllSem23.pdf
#
# === ANSWER ===
# The contact hours/week of Computer Architecture (PCC-CS402) is 3L/week.
#
# === SOURCES ===
# - IT/AllSem23.pdf
# - CSE/AllSem23.pdf
# - CSE/AllSem23.pdf
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
#
# === ANSWER ===
# The contact hours/week for Computer Architecture Lab (PCC-CS492) is 4P/week, where 'P' denotes practical hours.
#
# === SOURCES ===
# - IT/AllSem23.pdf
# - CSE/AllSem23.pdf
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
# - CSE/AllSem23.pdf
#
# === ANSWER ===
# I don't know the contact hours/week of Design & Analysis Algorithm Lab (PCC-CS494). The provided context only mentions the course code and semester, but not the contact hours. However, it does mention that there is a theory course with the code PCC-CS404 for Design and Analysis of Algorithms, which has 3L/week contact hours.
#
# === SOURCES ===
# - CSE/AllSem23.pdf
# - IT/AllSem23.pdf
# - Complete_Subject_Syllabus/IT_Complete_Syllabus.xlsx
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
#
# === ANSWER ===
# The contact hours/week for Design and Analysis of Algorithms (PCC-CS404) is 3L/week, which means 3 lecture hours per week.
#
# === SOURCES ===
# - IT/AllSem23.pdf
# - CSE/AllSem23.pdf
# - CSE/AllSem23.pdf
# - Complete_Subject_Syllabus/IT_Complete_Syllabus.xlsx
# - IT/AllSem23.pdf
#
# === ANSWER ===
# The contact hours/week for Discrete Mathematics (PCC-CS401) are 3L+1T, which means 3 lectures and 1 tutorial per week.
#
# === SOURCES ===
# - IT/AllSem23.pdf
# - ECE/ECE.pdf
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
#
# === ANSWER ===
# The contact hours/week for Environmental Sciences (MC-401) is 1L/week.
#
# === SOURCES ===
# - CSE/AllSem23.pdf
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
# - CSE/AllSem23.pdf
# - IT/AllSem23.pdf
#
# === ANSWER ===
# The contact hours/week for Formal Language & Automata Theory (PCC-CS403) is 3L/week.
#
# === SOURCES ===
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
# - CSE/AllSem23.pdf
# - IT/AllSem23.pdf
# - IT/AllSem23.pdf
# {'Biology (BSC)': 'Unknown', 'Computer Architecture (PCC-CS402)': '3L/week', 'Computer Architecture Lab (PCC-CS492)': '4P/week', 'Design &Analysis Algorithm Lab (PCC-CS494)': 'Unknown', 'Design and Analysis ofAlgorithms (PCC-CS404)': '3L/week', 'Discrete Mathematics (PCC-CS401)': '3L+1T', 'Environmental Sciences (MC-401)': '1L/week', 'Formal Language & Automata Theory (PCC-CS403)': '3L/week'}

# %%
sem = int(input("enter sem"))
variable = dept = input("enter department : (CSE,ECE,IT)")
# Out:
# enter sem 4
# enter department : (CSE,ECE,IT) CSE

# %%
import pandas as pd
import re
from collections import defaultdict
import random

class SmartRoutineGenerator:
    def __init__(self):
        self.time_slots = [
            '9-10', '10-11', '11-12', '12-1', '2-3', '3-4', '4-5'
        ]
        self.days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
        
    def load_data(self, faculty_file, room_file, student_file):
        """Load data from CSV/Excel files"""
        try:
            self.faculty_df = pd.read_excel(faculty_file) if faculty_file.endswith('.xlsx') else pd.read_csv(faculty_file)
            self.room_df = pd.read_excel(room_file) if room_file.endswith('.xlsx') else pd.read_csv(room_file)
            self.student_df = pd.read_excel(student_file) if student_file.endswith('.xlsx') else pd.read_csv(student_file)
            
            # Clean column names
            self.faculty_df.columns = self.faculty_df.columns.str.strip()
            self.room_df.columns = self.room_df.columns.str.strip()
            self.student_df.columns = self.student_df.columns.str.strip()
            
            print("Data loaded successfully!")
            
            # Debug: Show data structure
            print("\n[DEBUG] Faculty DataFrame Info:")
            print(f"Columns: {list(self.faculty_df.columns)}")
            print(f"Shape: {self.faculty_df.shape}")
            print("\nFirst few rows:")
            print(self.faculty_df.head())
            
            print("\n[DEBUG] Room DataFrame Info:")
            print(f"Columns: {list(self.room_df.columns)}")
            print(f"Shape: {self.room_df.shape}")
            print("\nFirst few rows:")
            print(self.room_df.head())
            
            print("\n[DEBUG] Student DataFrame Info:")
            print(f"Columns: {list(self.student_df.columns)}")
            print(f"Shape: {self.student_df.shape}")
            print("\nFirst few rows:")
            print(self.student_df.head())
            
            return True
        except Exception as e:
            print(f"Error loading data: {e}")
            return False
    
    def parse_contact_hours(self, contact_hour_string):
        """Parse contact hours string like '3L+1T', '4P/week', etc."""
        if not contact_hour_string or contact_hour_string == "Unknown":
            return {'L': 0, 'T': 0, 'P': 0}
        
        # Remove '/week' if present
        contact_hour_string = contact_hour_string.replace('/week', '')
        
        hours = {'L': 0, 'T': 0, 'P': 0}
        
        # Find all patterns like 3L, 1T, 4P
        matches = re.findall(r'(\d+)([LTP])', contact_hour_string)
        for count, type_char in matches:
            hours[type_char] = int(count)
        
        return hours
    
    def parse_unavailable_slots(self, unavailable_str):
        """Parse unavailable slots string"""
        if pd.isna(unavailable_str) or unavailable_str == "":
            return []
        
        slots = []
        # Split by comma and parse each slot
        for slot in str(unavailable_str).split(','):
            slot = slot.strip()
            if '-' in slot:
                # Format: "Mon 9-10" or "Mon 9-10, Tue 11-12"
                if ' ' in slot:
                    day, time = slot.split(' ', 1)
                    slots.append((day.strip(), time.strip()))
        return slots
    
    def parse_preferred_slots(self, preferred_str):
        """Parse preferred slots string"""
        if pd.isna(preferred_str) or preferred_str == "":
            return []
        
        slots = []
        for slot in str(preferred_str).split(','):
            slot = slot.strip()
            if '-' in slot:
                if ' ' in slot:
                    day, time = slot.split(' ', 1)
                    slots.append((day.strip(), time.strip()))
        return slots
    
    def get_suitable_rooms(self, subject_name, department, student_count):
        """Get suitable rooms for a subject"""
        # Determine room type needed
        if 'Lab' in subject_name or 'lab' in subject_name:
            room_type = 'Lab'
        else:
            room_type = 'Classroom'
        
        print(f"[DEBUG] Looking for {room_type} rooms for {subject_name}, capacity >= {student_count}")
        
        # First try: exact match
        suitable_rooms = self.room_df[
            (self.room_df['room_type'].str.contains(room_type, case=False, na=False)) &
            (self.room_df['capacity'] >= student_count) &
            ((self.room_df['department'].str.upper() == department.upper()) | 
             (self.room_df['department'].str.upper() == 'GENERAL'))
        ].copy()
        
        # If no rooms found, try more flexible matching
        if suitable_rooms.empty:
            print(f"[DEBUG] No exact match, trying flexible matching...")
            # Try any room with sufficient capacity
            suitable_rooms = self.room_df[
                (self.room_df['capacity'] >= student_count)
            ].copy()
            
            # If still no rooms, take any room (ignore capacity)
            if suitable_rooms.empty:
                print(f"[DEBUG] No capacity match, taking any available room...")
                suitable_rooms = self.room_df.copy()
        
        room_list = suitable_rooms['room_name'].tolist()
        print(f"[DEBUG] Found suitable rooms: {room_list}")
        return room_list
    
    def get_qualified_faculty(self, subject_name, department, year):
        """Get faculty who can teach a specific subject"""
        qualified_faculty = []
        
        print(f"[DEBUG] Looking for faculty for {subject_name} in {department} year {year}")
        print(f"[DEBUG] Available faculty: {list(self.faculty_df['name'])}")
        
        for _, faculty in self.faculty_df.iterrows():
            # Check if faculty teaches this subject
            faculty_subjects = str(faculty.get('subjects', '')).lower()
            faculty_name = faculty.get('name', '')
            
            print(f"[DEBUG] Checking {faculty_name}: subjects = '{faculty_subjects}'")
            
            # More flexible subject matching
            subject_keywords = []
            
            # Extract key terms from subject name
            if 'biology' in subject_name.lower():
                subject_keywords.extend(['biology', 'bio'])
            if 'computer architecture' in subject_name.lower():
                subject_keywords.extend(['computer architecture', 'architecture', 'computer'])
            if 'lab' in subject_name.lower():
                subject_keywords.extend(['lab', 'laboratory', 'practical'])
            if 'algorithm' in subject_name.lower():
                subject_keywords.extend(['algorithm', 'algorithms'])
            if 'discrete mathematics' in subject_name.lower():
                subject_keywords.extend(['discrete', 'mathematics', 'math'])
            if 'environmental' in subject_name.lower():
                subject_keywords.extend(['environmental', 'environment'])
            if 'formal language' in subject_name.lower() or 'automata' in subject_name.lower():
                subject_keywords.extend(['formal', 'language', 'automata', 'theory'])
            if 'object oriented' in subject_name.lower():
                subject_keywords.extend(['object', 'oriented', 'oop', 'programming'])
            
            # If no specific keywords, use the subject name words
            if not subject_keywords:
                subject_keywords = [word.lower().strip('()[]') for word in subject_name.split() 
                                  if len(word.strip('()[]')) > 2]
            
            print(f"[DEBUG] Subject keywords: {subject_keywords}")
            
            # Check if any keyword matches
            has_subject_match = any(keyword in faculty_subjects for keyword in subject_keywords)
            
            if has_subject_match or 'general' in faculty_subjects or 'all' in faculty_subjects:
                # Check department and year compatibility
                faculty_dept = str(faculty.get('department', '')).upper()
                faculty_year = str(faculty.get('year_to_teach', ''))
                
                print(f"[DEBUG] {faculty_name} - Dept: {faculty_dept}, Year: {faculty_year}")
                
                dept_match = (faculty_dept == department.upper() or 
                             faculty_dept == 'GENERAL' or 
                             faculty_dept == 'ALL')
                
                year_match = (str(year) in faculty_year or 
                             faculty_year.upper() == 'ALL' or
                             faculty_year == '')
                
                if dept_match and year_match:
                    qualified_faculty.append({
                        'name': faculty_name,
                        'max_load_hours': faculty.get('max_load_hours', 20),
                        'unavailable_slots': self.parse_unavailable_slots(faculty.get('unavailable_slots', '')),
                        'preferred_slots': self.parse_preferred_slots(faculty.get('preferred_slots', ''))
                    })
                    print(f"[DEBUG] ✓ {faculty_name} qualified for {subject_name}")
                else:
                    print(f"[DEBUG] ✗ {faculty_name} not qualified - dept_match: {dept_match}, year_match: {year_match}")
        
        print(f"[DEBUG] Qualified faculty for {subject_name}: {[f['name'] for f in qualified_faculty]}")
        return qualified_faculty
    
    def is_faculty_available(self, faculty_name, day, time_slot, faculty_schedule):
        """Check if faculty is available at given time"""
        return faculty_schedule.get(faculty_name, {}).get(day, {}).get(time_slot) is None
    
    def is_room_available(self, room_name, day, time_slot, room_schedule):
        """Check if room is available at given time"""
        return room_schedule.get(room_name, {}).get(day, {}).get(time_slot) is None
    
    def assign_class(self, subject_name, contact_hours, faculty_list, rooms, 
                    section, day, time_slot, faculty_schedule, room_schedule, 
                    faculty_workload, section_schedule):
        """Try to assign a single class"""
        
        # Try to find available faculty
        available_faculty = []
        for faculty in faculty_list:
            faculty_name = faculty['name']
            
            # Check availability
            if not self.is_faculty_available(faculty_name, day, time_slot, faculty_schedule):
                continue
            
            # Check unavailable slots
            unavailable = faculty['unavailable_slots']
            if (day, time_slot) in unavailable:
                continue
            
            # Check workload
            current_load = faculty_workload.get(faculty_name, 0)
            if current_load >= faculty['max_load_hours']:
                continue
            
            available_faculty.append(faculty)
        
        if not available_faculty:
            return None
        
        # Choose faculty (prefer those with preferred slots)
        chosen_faculty = None
        for faculty in available_faculty:
            preferred = faculty['preferred_slots']
            if (day, time_slot) in preferred:
                chosen_faculty = faculty
                break
        
        if not chosen_faculty:
            chosen_faculty = available_faculty[0]  # Take first available
        
        # Find available room
        available_rooms = []
        for room in rooms:
            if self.is_room_available(room, day, time_slot, room_schedule):
                available_rooms.append(room)
        
        if not available_rooms:
            return None
        
        chosen_room = available_rooms[0]
        faculty_name = chosen_faculty['name']
        
        # Make assignment
        if faculty_name not in faculty_schedule:
            faculty_schedule[faculty_name] = {}
        if day not in faculty_schedule[faculty_name]:
            faculty_schedule[faculty_name][day] = {}
        
        if chosen_room not in room_schedule:
            room_schedule[chosen_room] = {}
        if day not in room_schedule[chosen_room]:
            room_schedule[chosen_room][day] = {}
        
        faculty_schedule[faculty_name][day][time_slot] = f"{subject_name} - {section}"
        room_schedule[chosen_room][day][time_slot] = f"{subject_name} - {section}"
        faculty_workload[faculty_name] = faculty_workload.get(faculty_name, 0) + 1
        
        section_schedule[section][day][time_slot] = {
            'subject': subject_name,
            'faculty': faculty_name,
            'room': chosen_room
        }
        
        return True
    
    def generate_routine(self, dept, sem, contact_hours_dict):
        """Generate routine for all sections"""
        
        # Use the provided department and semester directly
        year = int(sem)
        
        # Get sections for this department and year
        sections_data = self.student_df[
            (self.student_df['department'] == dept) & 
            (self.student_df['year'] == year)
        ]
        
        if sections_data.empty:
            return f"No sections found for {dept} Year {year}"
        
        sections = sections_data['section'].tolist()
        
        # Initialize schedules
        faculty_schedule = {}
        room_schedule = {}
        faculty_workload = {}
        section_schedules = {}
        
        for section in sections:
            section_schedules[section] = {}
            for day in self.days:
                section_schedules[section][day] = {}
        
        # Process each subject
        for subject_name, contact_hours_str in contact_hours_dict.items():
            if contact_hours_str == "Unknown":
                continue
                
            contact_hours = self.parse_contact_hours(contact_hours_str)
            total_hours_needed = contact_hours['L'] + contact_hours['T'] + contact_hours['P']
            
            # Get qualified faculty and rooms for this subject
            qualified_faculty = self.get_qualified_faculty(subject_name, dept, year)
            
            # If no qualified faculty found, try to assign any available faculty
            if not qualified_faculty:
                print(f"[DEBUG] No qualified faculty found for {subject_name}, trying any available faculty...")
                for _, faculty in self.faculty_df.iterrows():
                    qualified_faculty.append({
                        'name': faculty['name'],
                        'max_load_hours': faculty.get('max_load_hours', 20),
                        'unavailable_slots': self.parse_unavailable_slots(faculty.get('unavailable_slots', '')),
                        'preferred_slots': self.parse_preferred_slots(faculty.get('preferred_slots', ''))
                    })
                    if len(qualified_faculty) >= 3:  # Limit to first 3 faculty
                        break
            if not qualified_faculty:
                print(f"No qualified faculty found for {subject_name}")
                continue
            
            # Get student count (try different column names)
            try:
                student_count = sections_data.iloc[0]['total_number_of_students']
            except KeyError:
                try:
                    student_count = sections_data.iloc[0]['total_students']
                except KeyError:
                    student_count = 50  # Default value
                    print(f"[DEBUG] Using default student count: {student_count}")
            
            suitable_rooms = self.get_suitable_rooms(subject_name, dept, student_count)
            
            if not suitable_rooms:
                print(f"[DEBUG] No suitable rooms found for {subject_name}, using any available room...")
                suitable_rooms = self.room_df['room_name'].tolist()[:3]  # Take first 3 rooms
            
            # Assign classes for each section
            for section in sections:
                classes_assigned = 0
                
                # Try to assign required number of classes
                for day in self.days:
                    if classes_assigned >= total_hours_needed:
                        break
                        
                    for time_slot in self.time_slots:
                        if classes_assigned >= total_hours_needed:
                            break
                        
                        # Check if slot is already occupied
                        if section_schedules[section][day].get(time_slot):
                            continue
                        
                        # Try to assign class
                        if self.assign_class(subject_name, contact_hours, qualified_faculty, 
                                           suitable_rooms, section, day, time_slot,
                                           faculty_schedule, room_schedule, 
                                           faculty_workload, section_schedules):
                            classes_assigned += 1
                
                if classes_assigned < total_hours_needed:
                    print(f"Warning: Could only assign {classes_assigned}/{total_hours_needed} classes for {subject_name} - Section {section}")
        
        return self.format_routine_output(section_schedules)
    
    def format_routine_output(self, section_schedules):
        """Format the routine output"""
        output = []
        
        for section in sorted(section_schedules.keys()):
            output.append(f"Routine for Section {section}:")
            
            for day in self.days:
                day_schedule = []
                day_schedule.append(f"{day}:")
                
                for time_slot in self.time_slots:
                    slot_info = section_schedules[section][day].get(time_slot)
                    if slot_info:
                        day_schedule.append(f"{time_slot}: {slot_info['subject']} by {slot_info['faculty']} in {slot_info['room']}")
                    else:
                        day_schedule.append(f"{time_slot}: Free")
                
                output.append(" ".join(day_schedule))
            
            output.append("")  # Empty line between sections
        
        return "\n".join(output)

# Function to generate routine with existing variables
def generate_smart_routine_from_variables(dept, sem, contact_hours_dict):
    """Main function to generate routine using existing variables"""
    
    generator = SmartRoutineGenerator()
    
    # Define Kaggle dataset paths
    dataset_dir = '/kaggle/input/college-data/'
    faculty_file = dataset_dir + 'faculty_assignments.csv'
    room_file = dataset_dir + 'room_assignments.csv'
    student_file = dataset_dir + 'student_sections.csv'
    
    # Check if files exist and try different extensions
    import os
    
    # Try different file extensions
    for ext in ['.csv', '.xlsx']:
        if os.path.exists(faculty_file.replace('.csv', ext)):
            faculty_file = faculty_file.replace('.csv', ext)
            break
    
    for ext in ['.csv', '.xlsx']:
        if os.path.exists(room_file.replace('.csv', ext)):
            room_file = room_file.replace('.csv', ext)
            break
            
    for ext in ['.csv', '.xlsx']:
        if os.path.exists(student_file.replace('.csv', ext)):
            student_file = student_file.replace('.csv', ext)
            break
    
    # Load data
    if not generator.load_data(faculty_file, room_file, student_file):
        return "Failed to load data files from Kaggle dataset"
    
    # Generate routine using department and semester directly
    routine = generator.generate_routine(dept, sem, contact_hours_dict)
    return routine

# Usage with your existing variables
# After getting your contact_hours_dict from RAG and having dept, sem variables

# Example of how to use in your existing code:
# Assuming you have:
# - dept = "CSE" (from your query parsing)  
# - sem = "4" (from your query parsing)
# - contact_hours_dict = {...} (from your RAG output)

# Simply call:
routine = generate_smart_routine_from_variables(dept, sem, contact_hours_dict)
print(routine)
# Out:
# Data loaded successfully!
#
# [DEBUG] Faculty DataFrame Info:
# Columns: ['faculty_id', 'name', 'department', 'subjects', 'year_to_teach', 'max_load_hours', 'unavailable_slots', 'preferred_slots']
# Shape: (60, 8)
#
# First few rows:
#   faculty_id          name department  \
# 0      F0001  Aarav Sharma        CSE
# 1      F0002    Isha Verma        CSE
# 2      F0003   Rohan Mehta        CSE
# 3      F0004    Neha Gupta        CSE
# 4      F0005  Aditya Singh        CSE
#
#                                             subjects year_to_teach  \
# 0  Data Structure & Algorithms|Mathematics IA|Phy...           1|2
# 1  Operating Systems|Database Management Systems|...           2|3
# 2  Computer Networks|Compiler Design|Machine Lear...           3|4
# 3  Artificial Intelligence|Formal Language & Auto...         2|3|4
# 4  Cloud Computing|Theory of Computation|Mathemat...       1|2|3|4
#
#    max_load_hours                unavailable_slots  \
# 0              16  Mon 10:00-12:00|Wed 14:00-16:00
# 1              18  Tue 13:00-15:00|Thu 09:00-10:00
# 2              14  Wed 11:00-13:00|Fri 14:00-16:00
# 3              20  Mon 09:00-10:00|Thu 13:00-15:00
# 4              16  Tue 11:00-13:00|Fri 09:00-10:00
#
#                    preferred_slots
# 0  Tue 09:00-11:00|Thu 11:00-13:00
# 1  Mon 09:00-11:00|Fri 10:00-12:00
# 2  Tue 10:00-12:00|Thu 15:00-17:00
# 3  Wed 10:00-12:00|Fri 09:00-11:00
# 4  Mon 14:00-16:00|Thu 10:00-12:00
#
# [DEBUG] Room DataFrame Info:
# Columns: ['room_id', 'room_name', 'capacity', 'room_type', 'department', 'equipment']
# Shape: (60, 6)
#
# First few rows:
#   room_id room_name  capacity room_type department  equipment
# 0   R0001    CSE-01        60    Theory        CSE  Projector
# 1   R0002    CSE-02        60    Theory        CSE  Projector
# 2   R0003    CSE-03        60    Theory        CSE  Projector
# 3   R0004    CSE-04        60    Theory        CSE  Projector
# 4   R0005    CSE-05        60    Theory        CSE  Projector
#
# [DEBUG] Student DataFrame Info:
# Columns: ['id', 'department', 'year', 'section', 'total_number_of_students']
# Shape: (36, 5)
#
# First few rows:
#      id department  year section  total_number_of_students
# 0  S001        CSE     1       A                        58
# 1  S002        CSE     1       B                        56
# 2  S003        CSE     1       C                        59
# 3  S004        CSE     2       A                        57
# 4  S005        CSE     2       B                        60
# [DEBUG] Looking for faculty for Computer Architecture (PCC-CS402) in CSE year 4
# [DEBUG] Available faculty: ['Aarav Sharma', 'Isha Verma', 'Rohan Mehta', 'Neha Gupta', 'Aditya Singh', 'Simran Kaur', 'Vikram Patel', 'Priyanka Rao', 'Sai Iyer', 'Karan Malhotra', 'Ananya Joshi', 'Manav Kapoor', 'Tanya Bansal', 'Nikhil Arora', 'Shreya Nair', 'Arjun Desai', 'Meera Kulkarni', 'Dev Khanna', 'Anushka Sethi', 'Harshit Goyal', 'Ritika Jain', 'Akash Dubey', 'Swati Chawla', 'Prateek Jain', 'Anika Reddy', 'Soham Sen', 'Divya Menon', 'Kunal Batra', 'Sneha Pillai', 'Varun Saxena', 'Anvi Bhatt', 'Aman Chawla', 'Krishna Rao', 'Mahek Shah', 'Ritvik Yadav', 'Diya Kapoor', 'Harshita Jain', 'Naveen Nair', 'Pooja Sinha', 'Samar Goel', 'Anil Krishnan', 'Keerthi Mohan', 'Suraj Kulkarni', 'Shruti Rao', 'Abhinav Patil', 'Vaishnavi Iyer', 'Parth Goswami', 'Ankita Deshmukh', 'Sharad Mishra', 'Komal Aggarwal', 'Sanjay Raval', 'Monica Dutta', 'Rajeev Nanda', 'Parul Soni', 'Deepak Rana', 'Nandini Iyer', 'Kartik Vora', 'Anu Mathew', 'Rehan Ali', 'Shilpa Menon']
# [DEBUG] Checking Aarav Sharma: subjects = 'data structure & algorithms|mathematics ia|physics-i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Isha Verma: subjects = 'operating systems|database management systems|software engineering'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Rohan Mehta: subjects = 'computer networks|compiler design|machine learning'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Rohan Mehta - Dept: CSE, Year: 3|4
# [DEBUG] ✓ Rohan Mehta qualified for Computer Architecture (PCC-CS402)
# [DEBUG] Checking Neha Gupta: subjects = 'artificial intelligence|formal language & automata theory|big data analytics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Aditya Singh: subjects = 'cloud computing|theory of computation|mathematics iia'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Simran Kaur: subjects = 'algorithms|computer organisation|computer networks lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Simran Kaur - Dept: CSE, Year: 2|3
# [DEBUG] ✗ Simran Kaur not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Vikram Patel: subjects = 'database management system lab|software engineering lab|introduction to industrial management'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Priyanka Rao: subjects = 'machine learning|project-ii|cryptography and network security'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Sai Iyer: subjects = 'web technologies|e-commerce & erp|physics-i laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Karan Malhotra: subjects = 'computer architecture|basic electrical engineering|basic electrical engineering lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Karan Malhotra - Dept: CSE, Year: 1|2
# [DEBUG] ✗ Karan Malhotra not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Ananya Joshi: subjects = 'programming for problem solving|programming for problem solving lab|chemistry-i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Manav Kapoor: subjects = 'project-iii|constitution of india|operation research'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Tanya Bansal: subjects = 'distributed systems|image processing|pattern recognition'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Nikhil Arora: subjects = 'adhoc – sensor network|soft computing|mathematics-iii'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Shreya Nair: subjects = 'analog and digital electronics|data structure & algorithm lab|computer organization lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Shreya Nair - Dept: CSE, Year: 2
# [DEBUG] ✗ Shreya Nair not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Arjun Desai: subjects = 'design and analysis of algorithms|design & analysis algorithm lab|workshop'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Meera Kulkarni: subjects = 'internet of things|mobile computing|chemistry-i laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Dev Khanna: subjects = 'project management and entrepreneurship|it workshop|english'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Anushka Sethi: subjects = 'biology|computer architecture lab|language laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Anushka Sethi - Dept: CSE, Year: 1|2
# [DEBUG] ✗ Anushka Sethi not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Harshit Goyal: subjects = 'discrete mathematics|environmental sciences|multimedia technology'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Ritika Jain: subjects = 'artificial intelligence|data base management system|computer graphics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Ritika Jain - Dept: IT, Year: 3
# [DEBUG] ✗ Ritika Jain not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Akash Dubey: subjects = 'computer networks|numerical methods|internet technology'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Akash Dubey - Dept: IT, Year: 3|4
# [DEBUG] ✗ Akash Dubey not qualified - dept_match: False, year_match: True
# [DEBUG] Checking Swati Chawla: subjects = 'software engineering|object oriented programming|data structure & algorithm'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Prateek Jain: subjects = 'cryptography & network security|e-commerce & erp|microelectronics & vlsi design'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Anika Reddy: subjects = 'cloud computing|cyber security|soft skills & interpersonal communication'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Soham Sen: subjects = 'project-ii|computer architecture|formal language & automata theory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Soham Sen - Dept: IT, Year: 2|4
# [DEBUG] ✗ Soham Sen not qualified - dept_match: False, year_match: True
# [DEBUG] Checking Divya Menon: subjects = 'image processing|pattern recognition|mathematics ia'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Kunal Batra: subjects = 'advanced algorithm|parallel and distributed algorithms|physics-i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Kunal Batra - Dept: IT, Year: 1|3
# [DEBUG] ✗ Kunal Batra not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Sneha Pillai: subjects = 'data base management system lab|computer networking lab|physics-i laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Sneha Pillai - Dept: IT, Year: 3
# [DEBUG] ✗ Sneha Pillai not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Varun Saxena: subjects = 'programming for problem solving|programming for problem solving lab|chemistry-i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Anvi Bhatt: subjects = 'analog & digital electronics|analog and digital electronics lab|mathematics iia'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Aman Chawla: subjects = 'computer organization|computer organization lab|english'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Aman Chawla - Dept: IT, Year: 1|2
# [DEBUG] ✗ Aman Chawla not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Krishna Rao: subjects = 'data structure & algorithm lab|it workshop|basic electrical engineering'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Mahek Shah: subjects = 'environmental sciences|constitution of india|chemistry-i lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Ritvik Yadav: subjects = 'software engineering lab|object oriented programming lab|basic electrical engineering lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Diya Kapoor: subjects = 'research methodology|workshop|language laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Harshita Jain: subjects = 'design & analysis of algorithm|computer architecture lab|mathematics-iii'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Harshita Jain - Dept: IT, Year: 2
# [DEBUG] ✗ Harshita Jain not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Naveen Nair: subjects = 'economics for engineers|operating system lab|engineering graphics & design'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Pooja Sinha: subjects = 'compiler design|discrete mathematics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Samar Goel: subjects = 'basic electrical engineering lab|chemistry-i lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Anil Krishnan: subjects = 'electronic devices|digital system design|signals and systems'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Keerthi Mohan: subjects = 'electromagnetic waves|analog communication|network theory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Suraj Kulkarni: subjects = 'microprocessor & microcontrollers|digital signal processing|power electronics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Shruti Rao: subjects = 'embedded system|antennas and propagation|internet of things'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Abhinav Patil: subjects = 'electronic devices lab|digital system design lab|data structure lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Vaishnavi Iyer: subjects = 'analog electronic circuits|analog communication lab|electromagnetic wave lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Parth Goswami: subjects = 'control system & instrumentation|microprocessor & microcontrollers lab|computer network'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Parth Goswami - Dept: ECE, Year: 3
# [DEBUG] ✗ Parth Goswami not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Ankita Deshmukh: subjects = 'digital signal processing lab|nano electronics|speech and audio processing'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Sharad Mishra: subjects = 'fibre optic communication|microwave theory and techniques|project stage i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Komal Aggarwal: subjects = 'environmental science|probability & statistics|data structure & algorithm'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Sanjay Raval: subjects = 'analog electronic circuits lab|numerical methods|numerical methods lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Monica Dutta: subjects = 'project stage ii|grand viva|bio-medical electronics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Rajeev Nanda: subjects = 'cmos vlsi design|information theory & coding|digital communication & stochastic process'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Parul Soni: subjects = 'satellite communication|mobile communication and networks|wireless sensor networks'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Deepak Rana: subjects = 'control system and instrumentation lab|mini project/ electronic design workshop|economics for engineers'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Nandini Iyer: subjects = 'adaptive signal processing|digital image and video processing|neural network and fuzzy logic control'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Kartik Vora: subjects = 'computer network lab|scientific computing|soft skill and interpersonal communication'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Kartik Vora - Dept: ECE, Year: 3
# [DEBUG] ✗ Kartik Vora not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Anu Mathew: subjects = 'web technology|optimisation technique|entrepreneurship'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Rehan Ali: subjects = 'cyber law & intellectual property rights|human resource management|universal human values'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Checking Shilpa Menon: subjects = 'introduction to mems|electronic measurements and measuring instruments|operating system'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer']
# [DEBUG] Qualified faculty for Computer Architecture (PCC-CS402): ['Rohan Mehta']
# [DEBUG] Looking for Classroom rooms for Computer Architecture (PCC-CS402), capacity >= 59
# [DEBUG] No exact match, trying flexible matching...
# [DEBUG] Found suitable rooms: ['CSE-01', 'CSE-02', 'CSE-03', 'CSE-04', 'CSE-05', 'CSE-06', 'CSE-07', 'CSE-08', 'CSE-09', 'CSE-10', 'CSE-11', 'CSE-12', 'CSE-13', 'CSE-14', 'IT-01', 'IT-02', 'IT-03', 'IT-04', 'IT-05', 'IT-06', 'IT-07', 'IT-08', 'IT-09', 'IT-10', 'IT-11', 'IT-12', 'IT-13', 'IT-14', 'ECE-01', 'ECE-02', 'ECE-03', 'ECE-04', 'ECE-05', 'ECE-06', 'ECE-07', 'ECE-08', 'ECE-09', 'ECE-10', 'ECE-11', 'ECE-12', 'ECE-13', 'ECE-14']
# [DEBUG] Looking for faculty for Computer Architecture Lab (PCC-CS492) in CSE year 4
# [DEBUG] Available faculty: ['Aarav Sharma', 'Isha Verma', 'Rohan Mehta', 'Neha Gupta', 'Aditya Singh', 'Simran Kaur', 'Vikram Patel', 'Priyanka Rao', 'Sai Iyer', 'Karan Malhotra', 'Ananya Joshi', 'Manav Kapoor', 'Tanya Bansal', 'Nikhil Arora', 'Shreya Nair', 'Arjun Desai', 'Meera Kulkarni', 'Dev Khanna', 'Anushka Sethi', 'Harshit Goyal', 'Ritika Jain', 'Akash Dubey', 'Swati Chawla', 'Prateek Jain', 'Anika Reddy', 'Soham Sen', 'Divya Menon', 'Kunal Batra', 'Sneha Pillai', 'Varun Saxena', 'Anvi Bhatt', 'Aman Chawla', 'Krishna Rao', 'Mahek Shah', 'Ritvik Yadav', 'Diya Kapoor', 'Harshita Jain', 'Naveen Nair', 'Pooja Sinha', 'Samar Goel', 'Anil Krishnan', 'Keerthi Mohan', 'Suraj Kulkarni', 'Shruti Rao', 'Abhinav Patil', 'Vaishnavi Iyer', 'Parth Goswami', 'Ankita Deshmukh', 'Sharad Mishra', 'Komal Aggarwal', 'Sanjay Raval', 'Monica Dutta', 'Rajeev Nanda', 'Parul Soni', 'Deepak Rana', 'Nandini Iyer', 'Kartik Vora', 'Anu Mathew', 'Rehan Ali', 'Shilpa Menon']
# [DEBUG] Checking Aarav Sharma: subjects = 'data structure & algorithms|mathematics ia|physics-i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Isha Verma: subjects = 'operating systems|database management systems|software engineering'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Rohan Mehta: subjects = 'computer networks|compiler design|machine learning'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Rohan Mehta - Dept: CSE, Year: 3|4
# [DEBUG] ✓ Rohan Mehta qualified for Computer Architecture Lab (PCC-CS492)
# [DEBUG] Checking Neha Gupta: subjects = 'artificial intelligence|formal language & automata theory|big data analytics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Aditya Singh: subjects = 'cloud computing|theory of computation|mathematics iia'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Simran Kaur: subjects = 'algorithms|computer organisation|computer networks lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Simran Kaur - Dept: CSE, Year: 2|3
# [DEBUG] ✗ Simran Kaur not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Vikram Patel: subjects = 'database management system lab|software engineering lab|introduction to industrial management'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Vikram Patel - Dept: CSE, Year: 2|3
# [DEBUG] ✗ Vikram Patel not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Priyanka Rao: subjects = 'machine learning|project-ii|cryptography and network security'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Sai Iyer: subjects = 'web technologies|e-commerce & erp|physics-i laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Sai Iyer - Dept: CSE, Year: 1|4
# [DEBUG] ✓ Sai Iyer qualified for Computer Architecture Lab (PCC-CS492)
# [DEBUG] Checking Karan Malhotra: subjects = 'computer architecture|basic electrical engineering|basic electrical engineering lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Karan Malhotra - Dept: CSE, Year: 1|2
# [DEBUG] ✗ Karan Malhotra not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Ananya Joshi: subjects = 'programming for problem solving|programming for problem solving lab|chemistry-i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Ananya Joshi - Dept: CSE, Year: 1
# [DEBUG] ✗ Ananya Joshi not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Manav Kapoor: subjects = 'project-iii|constitution of india|operation research'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Tanya Bansal: subjects = 'distributed systems|image processing|pattern recognition'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Nikhil Arora: subjects = 'adhoc – sensor network|soft computing|mathematics-iii'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Shreya Nair: subjects = 'analog and digital electronics|data structure & algorithm lab|computer organization lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Shreya Nair - Dept: CSE, Year: 2
# [DEBUG] ✗ Shreya Nair not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Arjun Desai: subjects = 'design and analysis of algorithms|design & analysis algorithm lab|workshop'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Arjun Desai - Dept: CSE, Year: 1|2
# [DEBUG] ✗ Arjun Desai not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Meera Kulkarni: subjects = 'internet of things|mobile computing|chemistry-i laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Meera Kulkarni - Dept: CSE, Year: 1|4
# [DEBUG] ✓ Meera Kulkarni qualified for Computer Architecture Lab (PCC-CS492)
# [DEBUG] Checking Dev Khanna: subjects = 'project management and entrepreneurship|it workshop|english'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Anushka Sethi: subjects = 'biology|computer architecture lab|language laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Anushka Sethi - Dept: CSE, Year: 1|2
# [DEBUG] ✗ Anushka Sethi not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Harshit Goyal: subjects = 'discrete mathematics|environmental sciences|multimedia technology'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Ritika Jain: subjects = 'artificial intelligence|data base management system|computer graphics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Ritika Jain - Dept: IT, Year: 3
# [DEBUG] ✗ Ritika Jain not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Akash Dubey: subjects = 'computer networks|numerical methods|internet technology'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Akash Dubey - Dept: IT, Year: 3|4
# [DEBUG] ✗ Akash Dubey not qualified - dept_match: False, year_match: True
# [DEBUG] Checking Swati Chawla: subjects = 'software engineering|object oriented programming|data structure & algorithm'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Prateek Jain: subjects = 'cryptography & network security|e-commerce & erp|microelectronics & vlsi design'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Anika Reddy: subjects = 'cloud computing|cyber security|soft skills & interpersonal communication'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Soham Sen: subjects = 'project-ii|computer architecture|formal language & automata theory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Soham Sen - Dept: IT, Year: 2|4
# [DEBUG] ✗ Soham Sen not qualified - dept_match: False, year_match: True
# [DEBUG] Checking Divya Menon: subjects = 'image processing|pattern recognition|mathematics ia'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Kunal Batra: subjects = 'advanced algorithm|parallel and distributed algorithms|physics-i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Kunal Batra - Dept: IT, Year: 1|3
# [DEBUG] ✗ Kunal Batra not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Sneha Pillai: subjects = 'data base management system lab|computer networking lab|physics-i laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Sneha Pillai - Dept: IT, Year: 3
# [DEBUG] ✗ Sneha Pillai not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Varun Saxena: subjects = 'programming for problem solving|programming for problem solving lab|chemistry-i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Varun Saxena - Dept: IT, Year: 1
# [DEBUG] ✗ Varun Saxena not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Anvi Bhatt: subjects = 'analog & digital electronics|analog and digital electronics lab|mathematics iia'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Anvi Bhatt - Dept: IT, Year: 1|2
# [DEBUG] ✗ Anvi Bhatt not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Aman Chawla: subjects = 'computer organization|computer organization lab|english'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Aman Chawla - Dept: IT, Year: 1|2
# [DEBUG] ✗ Aman Chawla not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Krishna Rao: subjects = 'data structure & algorithm lab|it workshop|basic electrical engineering'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Krishna Rao - Dept: IT, Year: 1|2
# [DEBUG] ✗ Krishna Rao not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Mahek Shah: subjects = 'environmental sciences|constitution of india|chemistry-i lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Mahek Shah - Dept: IT, Year: 1|3
# [DEBUG] ✗ Mahek Shah not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Ritvik Yadav: subjects = 'software engineering lab|object oriented programming lab|basic electrical engineering lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Ritvik Yadav - Dept: IT, Year: 1|3
# [DEBUG] ✗ Ritvik Yadav not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Diya Kapoor: subjects = 'research methodology|workshop|language laboratory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Diya Kapoor - Dept: IT, Year: 1|3
# [DEBUG] ✗ Diya Kapoor not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Harshita Jain: subjects = 'design & analysis of algorithm|computer architecture lab|mathematics-iii'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Harshita Jain - Dept: IT, Year: 2
# [DEBUG] ✗ Harshita Jain not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Naveen Nair: subjects = 'economics for engineers|operating system lab|engineering graphics & design'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Naveen Nair - Dept: IT, Year: 1|2|3
# [DEBUG] ✗ Naveen Nair not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Pooja Sinha: subjects = 'compiler design|discrete mathematics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Samar Goel: subjects = 'basic electrical engineering lab|chemistry-i lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Samar Goel - Dept: IT, Year: 1
# [DEBUG] ✗ Samar Goel not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Anil Krishnan: subjects = 'electronic devices|digital system design|signals and systems'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Keerthi Mohan: subjects = 'electromagnetic waves|analog communication|network theory'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Suraj Kulkarni: subjects = 'microprocessor & microcontrollers|digital signal processing|power electronics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Shruti Rao: subjects = 'embedded system|antennas and propagation|internet of things'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Abhinav Patil: subjects = 'electronic devices lab|digital system design lab|data structure lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Abhinav Patil - Dept: ECE, Year: 2
# [DEBUG] ✗ Abhinav Patil not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Vaishnavi Iyer: subjects = 'analog electronic circuits|analog communication lab|electromagnetic wave lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Vaishnavi Iyer - Dept: ECE, Year: 2|3
# [DEBUG] ✗ Vaishnavi Iyer not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Parth Goswami: subjects = 'control system & instrumentation|microprocessor & microcontrollers lab|computer network'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Parth Goswami - Dept: ECE, Year: 3
# [DEBUG] ✗ Parth Goswami not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Ankita Deshmukh: subjects = 'digital signal processing lab|nano electronics|speech and audio processing'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Ankita Deshmukh - Dept: ECE, Year: 3
# [DEBUG] ✗ Ankita Deshmukh not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Sharad Mishra: subjects = 'fibre optic communication|microwave theory and techniques|project stage i'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Komal Aggarwal: subjects = 'environmental science|probability & statistics|data structure & algorithm'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Sanjay Raval: subjects = 'analog electronic circuits lab|numerical methods|numerical methods lab'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Sanjay Raval - Dept: ECE, Year: 2
# [DEBUG] ✗ Sanjay Raval not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Monica Dutta: subjects = 'project stage ii|grand viva|bio-medical electronics'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Rajeev Nanda: subjects = 'cmos vlsi design|information theory & coding|digital communication & stochastic process'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Parul Soni: subjects = 'satellite communication|mobile communication and networks|wireless sensor networks'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Deepak Rana: subjects = 'control system and instrumentation lab|mini project/ electronic design workshop|economics for engineers'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Deepak Rana - Dept: ECE, Year: 3
# [DEBUG] ✗ Deepak Rana not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Nandini Iyer: subjects = 'adaptive signal processing|digital image and video processing|neural network and fuzzy logic control'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Kartik Vora: subjects = 'computer network lab|scientific computing|soft skill and interpersonal communication'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Kartik Vora - Dept: ECE, Year: 3
# [DEBUG] ✗ Kartik Vora not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Anu Mathew: subjects = 'web technology|optimisation technique|entrepreneurship'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Rehan Ali: subjects = 'cyber law & intellectual property rights|human resource management|universal human values'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Checking Shilpa Menon: subjects = 'introduction to mems|electronic measurements and measuring instruments|operating system'
# [DEBUG] Subject keywords: ['computer architecture', 'architecture', 'computer', 'lab', 'laboratory', 'practical']
# [DEBUG] Qualified faculty for Computer Architecture Lab (PCC-CS492): ['Rohan Mehta', 'Sai Iyer', 'Meera Kulkarni']
# [DEBUG] Looking for Lab rooms for Computer Architecture Lab (PCC-CS492), capacity >= 59
# [DEBUG] No exact match, trying flexible matching...
# [DEBUG] Found suitable rooms: ['CSE-01', 'CSE-02', 'CSE-03', 'CSE-04', 'CSE-05', 'CSE-06', 'CSE-07', 'CSE-08', 'CSE-09', 'CSE-10', 'CSE-11', 'CSE-12', 'CSE-13', 'CSE-14', 'IT-01', 'IT-02', 'IT-03', 'IT-04', 'IT-05', 'IT-06', 'IT-07', 'IT-08', 'IT-09', 'IT-10', 'IT-11', 'IT-12', 'IT-13', 'IT-14', 'ECE-01', 'ECE-02', 'ECE-03', 'ECE-04', 'ECE-05', 'ECE-06', 'ECE-07', 'ECE-08', 'ECE-09', 'ECE-10', 'ECE-11', 'ECE-12', 'ECE-13', 'ECE-14']
# [DEBUG] Looking for faculty for Design and Analysis ofAlgorithms (PCC-CS404) in CSE year 4
# [DEBUG] Available faculty: ['Aarav Sharma', 'Isha Verma', 'Rohan Mehta', 'Neha Gupta', 'Aditya Singh', 'Simran Kaur', 'Vikram Patel', 'Priyanka Rao', 'Sai Iyer', 'Karan Malhotra', 'Ananya Joshi', 'Manav Kapoor', 'Tanya Bansal', 'Nikhil Arora', 'Shreya Nair', 'Arjun Desai', 'Meera Kulkarni', 'Dev Khanna', 'Anushka Sethi', 'Harshit Goyal', 'Ritika Jain', 'Akash Dubey', 'Swati Chawla', 'Prateek Jain', 'Anika Reddy', 'Soham Sen', 'Divya Menon', 'Kunal Batra', 'Sneha Pillai', 'Varun Saxena', 'Anvi Bhatt', 'Aman Chawla', 'Krishna Rao', 'Mahek Shah', 'Ritvik Yadav', 'Diya Kapoor', 'Harshita Jain', 'Naveen Nair', 'Pooja Sinha', 'Samar Goel', 'Anil Krishnan', 'Keerthi Mohan', 'Suraj Kulkarni', 'Shruti Rao', 'Abhinav Patil', 'Vaishnavi Iyer', 'Parth Goswami', 'Ankita Deshmukh', 'Sharad Mishra', 'Komal Aggarwal', 'Sanjay Raval', 'Monica Dutta', 'Rajeev Nanda', 'Parul Soni', 'Deepak Rana', 'Nandini Iyer', 'Kartik Vora', 'Anu Mathew', 'Rehan Ali', 'Shilpa Menon']
# [DEBUG] Checking Aarav Sharma: subjects = 'data structure & algorithms|mathematics ia|physics-i'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Aarav Sharma - Dept: CSE, Year: 1|2
# [DEBUG] ✗ Aarav Sharma not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Isha Verma: subjects = 'operating systems|database management systems|software engineering'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Rohan Mehta: subjects = 'computer networks|compiler design|machine learning'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Neha Gupta: subjects = 'artificial intelligence|formal language & automata theory|big data analytics'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Aditya Singh: subjects = 'cloud computing|theory of computation|mathematics iia'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Simran Kaur: subjects = 'algorithms|computer organisation|computer networks lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Simran Kaur - Dept: CSE, Year: 2|3
# [DEBUG] ✗ Simran Kaur not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Vikram Patel: subjects = 'database management system lab|software engineering lab|introduction to industrial management'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Priyanka Rao: subjects = 'machine learning|project-ii|cryptography and network security'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Sai Iyer: subjects = 'web technologies|e-commerce & erp|physics-i laboratory'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Karan Malhotra: subjects = 'computer architecture|basic electrical engineering|basic electrical engineering lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Ananya Joshi: subjects = 'programming for problem solving|programming for problem solving lab|chemistry-i'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Manav Kapoor: subjects = 'project-iii|constitution of india|operation research'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Tanya Bansal: subjects = 'distributed systems|image processing|pattern recognition'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Nikhil Arora: subjects = 'adhoc – sensor network|soft computing|mathematics-iii'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Shreya Nair: subjects = 'analog and digital electronics|data structure & algorithm lab|computer organization lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Shreya Nair - Dept: CSE, Year: 2
# [DEBUG] ✗ Shreya Nair not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Arjun Desai: subjects = 'design and analysis of algorithms|design & analysis algorithm lab|workshop'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Arjun Desai - Dept: CSE, Year: 1|2
# [DEBUG] ✗ Arjun Desai not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Meera Kulkarni: subjects = 'internet of things|mobile computing|chemistry-i laboratory'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Dev Khanna: subjects = 'project management and entrepreneurship|it workshop|english'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Anushka Sethi: subjects = 'biology|computer architecture lab|language laboratory'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Harshit Goyal: subjects = 'discrete mathematics|environmental sciences|multimedia technology'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Ritika Jain: subjects = 'artificial intelligence|data base management system|computer graphics'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Akash Dubey: subjects = 'computer networks|numerical methods|internet technology'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Swati Chawla: subjects = 'software engineering|object oriented programming|data structure & algorithm'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Swati Chawla - Dept: IT, Year: 2|3
# [DEBUG] ✗ Swati Chawla not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Prateek Jain: subjects = 'cryptography & network security|e-commerce & erp|microelectronics & vlsi design'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Anika Reddy: subjects = 'cloud computing|cyber security|soft skills & interpersonal communication'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Soham Sen: subjects = 'project-ii|computer architecture|formal language & automata theory'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Divya Menon: subjects = 'image processing|pattern recognition|mathematics ia'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Kunal Batra: subjects = 'advanced algorithm|parallel and distributed algorithms|physics-i'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Kunal Batra - Dept: IT, Year: 1|3
# [DEBUG] ✗ Kunal Batra not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Sneha Pillai: subjects = 'data base management system lab|computer networking lab|physics-i laboratory'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Varun Saxena: subjects = 'programming for problem solving|programming for problem solving lab|chemistry-i'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Anvi Bhatt: subjects = 'analog & digital electronics|analog and digital electronics lab|mathematics iia'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Aman Chawla: subjects = 'computer organization|computer organization lab|english'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Krishna Rao: subjects = 'data structure & algorithm lab|it workshop|basic electrical engineering'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Krishna Rao - Dept: IT, Year: 1|2
# [DEBUG] ✗ Krishna Rao not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Mahek Shah: subjects = 'environmental sciences|constitution of india|chemistry-i lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Ritvik Yadav: subjects = 'software engineering lab|object oriented programming lab|basic electrical engineering lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Diya Kapoor: subjects = 'research methodology|workshop|language laboratory'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Harshita Jain: subjects = 'design & analysis of algorithm|computer architecture lab|mathematics-iii'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Harshita Jain - Dept: IT, Year: 2
# [DEBUG] ✗ Harshita Jain not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Naveen Nair: subjects = 'economics for engineers|operating system lab|engineering graphics & design'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Pooja Sinha: subjects = 'compiler design|discrete mathematics'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Samar Goel: subjects = 'basic electrical engineering lab|chemistry-i lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Anil Krishnan: subjects = 'electronic devices|digital system design|signals and systems'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Keerthi Mohan: subjects = 'electromagnetic waves|analog communication|network theory'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Suraj Kulkarni: subjects = 'microprocessor & microcontrollers|digital signal processing|power electronics'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Shruti Rao: subjects = 'embedded system|antennas and propagation|internet of things'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Abhinav Patil: subjects = 'electronic devices lab|digital system design lab|data structure lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Vaishnavi Iyer: subjects = 'analog electronic circuits|analog communication lab|electromagnetic wave lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Parth Goswami: subjects = 'control system & instrumentation|microprocessor & microcontrollers lab|computer network'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Ankita Deshmukh: subjects = 'digital signal processing lab|nano electronics|speech and audio processing'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Sharad Mishra: subjects = 'fibre optic communication|microwave theory and techniques|project stage i'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Komal Aggarwal: subjects = 'environmental science|probability & statistics|data structure & algorithm'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Komal Aggarwal - Dept: ECE, Year: 2
# [DEBUG] ✗ Komal Aggarwal not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Sanjay Raval: subjects = 'analog electronic circuits lab|numerical methods|numerical methods lab'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Monica Dutta: subjects = 'project stage ii|grand viva|bio-medical electronics'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Rajeev Nanda: subjects = 'cmos vlsi design|information theory & coding|digital communication & stochastic process'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Parul Soni: subjects = 'satellite communication|mobile communication and networks|wireless sensor networks'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Deepak Rana: subjects = 'control system and instrumentation lab|mini project/ electronic design workshop|economics for engineers'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# [DEBUG] Checking Nandini Iyer: subjects = 'adaptive signal processing|digital image and video processing|neural network and fuzzy logic control'
# [DEBUG] Subject keywords: ['algorithm', 'algorithms']
# ...
# [DEBUG] Checking Vikram Patel: subjects = 'database management system lab|software engineering lab|introduction to industrial management'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Priyanka Rao: subjects = 'machine learning|project-ii|cryptography and network security'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Sai Iyer: subjects = 'web technologies|e-commerce & erp|physics-i laboratory'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Karan Malhotra: subjects = 'computer architecture|basic electrical engineering|basic electrical engineering lab'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Ananya Joshi: subjects = 'programming for problem solving|programming for problem solving lab|chemistry-i'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Manav Kapoor: subjects = 'project-iii|constitution of india|operation research'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Tanya Bansal: subjects = 'distributed systems|image processing|pattern recognition'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Nikhil Arora: subjects = 'adhoc – sensor network|soft computing|mathematics-iii'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Shreya Nair: subjects = 'analog and digital electronics|data structure & algorithm lab|computer organization lab'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Arjun Desai: subjects = 'design and analysis of algorithms|design & analysis algorithm lab|workshop'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Meera Kulkarni: subjects = 'internet of things|mobile computing|chemistry-i laboratory'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Dev Khanna: subjects = 'project management and entrepreneurship|it workshop|english'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Anushka Sethi: subjects = 'biology|computer architecture lab|language laboratory'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Anushka Sethi - Dept: CSE, Year: 1|2
# [DEBUG] ✗ Anushka Sethi not qualified - dept_match: True, year_match: False
# [DEBUG] Checking Harshit Goyal: subjects = 'discrete mathematics|environmental sciences|multimedia technology'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Ritika Jain: subjects = 'artificial intelligence|data base management system|computer graphics'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Akash Dubey: subjects = 'computer networks|numerical methods|internet technology'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Swati Chawla: subjects = 'software engineering|object oriented programming|data structure & algorithm'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Prateek Jain: subjects = 'cryptography & network security|e-commerce & erp|microelectronics & vlsi design'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Anika Reddy: subjects = 'cloud computing|cyber security|soft skills & interpersonal communication'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Soham Sen: subjects = 'project-ii|computer architecture|formal language & automata theory'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Soham Sen - Dept: IT, Year: 2|4
# [DEBUG] ✗ Soham Sen not qualified - dept_match: False, year_match: True
# [DEBUG] Checking Divya Menon: subjects = 'image processing|pattern recognition|mathematics ia'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Kunal Batra: subjects = 'advanced algorithm|parallel and distributed algorithms|physics-i'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Kunal Batra - Dept: IT, Year: 1|3
# [DEBUG] ✗ Kunal Batra not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Sneha Pillai: subjects = 'data base management system lab|computer networking lab|physics-i laboratory'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Varun Saxena: subjects = 'programming for problem solving|programming for problem solving lab|chemistry-i'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Anvi Bhatt: subjects = 'analog & digital electronics|analog and digital electronics lab|mathematics iia'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Aman Chawla: subjects = 'computer organization|computer organization lab|english'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Krishna Rao: subjects = 'data structure & algorithm lab|it workshop|basic electrical engineering'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Mahek Shah: subjects = 'environmental sciences|constitution of india|chemistry-i lab'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Ritvik Yadav: subjects = 'software engineering lab|object oriented programming lab|basic electrical engineering lab'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Diya Kapoor: subjects = 'research methodology|workshop|language laboratory'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Diya Kapoor - Dept: IT, Year: 1|3
# [DEBUG] ✗ Diya Kapoor not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Harshita Jain: subjects = 'design & analysis of algorithm|computer architecture lab|mathematics-iii'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Naveen Nair: subjects = 'economics for engineers|operating system lab|engineering graphics & design'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Pooja Sinha: subjects = 'compiler design|discrete mathematics'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Samar Goel: subjects = 'basic electrical engineering lab|chemistry-i lab'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Anil Krishnan: subjects = 'electronic devices|digital system design|signals and systems'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Keerthi Mohan: subjects = 'electromagnetic waves|analog communication|network theory'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Keerthi Mohan - Dept: ECE, Year: 2|3
# [DEBUG] ✗ Keerthi Mohan not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Suraj Kulkarni: subjects = 'microprocessor & microcontrollers|digital signal processing|power electronics'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Shruti Rao: subjects = 'embedded system|antennas and propagation|internet of things'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Abhinav Patil: subjects = 'electronic devices lab|digital system design lab|data structure lab'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Vaishnavi Iyer: subjects = 'analog electronic circuits|analog communication lab|electromagnetic wave lab'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Parth Goswami: subjects = 'control system & instrumentation|microprocessor & microcontrollers lab|computer network'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Ankita Deshmukh: subjects = 'digital signal processing lab|nano electronics|speech and audio processing'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Sharad Mishra: subjects = 'fibre optic communication|microwave theory and techniques|project stage i'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Sharad Mishra - Dept: ECE, Year: 4
# [DEBUG] ✗ Sharad Mishra not qualified - dept_match: False, year_match: True
# [DEBUG] Checking Komal Aggarwal: subjects = 'environmental science|probability & statistics|data structure & algorithm'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Sanjay Raval: subjects = 'analog electronic circuits lab|numerical methods|numerical methods lab'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Monica Dutta: subjects = 'project stage ii|grand viva|bio-medical electronics'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Rajeev Nanda: subjects = 'cmos vlsi design|information theory & coding|digital communication & stochastic process'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Rajeev Nanda - Dept: ECE, Year: 3
# [DEBUG] ✗ Rajeev Nanda not qualified - dept_match: False, year_match: False
# [DEBUG] Checking Parul Soni: subjects = 'satellite communication|mobile communication and networks|wireless sensor networks'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Deepak Rana: subjects = 'control system and instrumentation lab|mini project/ electronic design workshop|economics for engineers'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Nandini Iyer: subjects = 'adaptive signal processing|digital image and video processing|neural network and fuzzy logic control'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Kartik Vora: subjects = 'computer network lab|scientific computing|soft skill and interpersonal communication'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Anu Mathew: subjects = 'web technology|optimisation technique|entrepreneurship'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Rehan Ali: subjects = 'cyber law & intellectual property rights|human resource management|universal human values'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Checking Shilpa Menon: subjects = 'introduction to mems|electronic measurements and measuring instruments|operating system'
# [DEBUG] Subject keywords: ['formal', 'language', 'automata', 'theory']
# [DEBUG] Qualified faculty for Formal Language & Automata Theory (PCC-CS403): ['Neha Gupta', 'Aditya Singh']
# [DEBUG] Looking for Classroom rooms for Formal Language & Automata Theory (PCC-CS403), capacity >= 59
# [DEBUG] No exact match, trying flexible matching...
# [DEBUG] Found suitable rooms: ['CSE-01', 'CSE-02', 'CSE-03', 'CSE-04', 'CSE-05', 'CSE-06', 'CSE-07', 'CSE-08', 'CSE-09', 'CSE-10', 'CSE-11', 'CSE-12', 'CSE-13', 'CSE-14', 'IT-01', 'IT-02', 'IT-03', 'IT-04', 'IT-05', 'IT-06', 'IT-07', 'IT-08', 'IT-09', 'IT-10', 'IT-11', 'IT-12', 'IT-13', 'IT-14', 'ECE-01', 'ECE-02', 'ECE-03', 'ECE-04', 'ECE-05', 'ECE-06', 'ECE-07', 'ECE-08', 'ECE-09', 'ECE-10', 'ECE-11', 'ECE-12', 'ECE-13', 'ECE-14']
# Routine for Section A:
# Mon: 9-10: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01 10-11: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01 11-12: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01 12-1: Computer Architecture Lab (PCC-CS492) by Sai Iyer in CSE-02 2-3: Computer Architecture Lab (PCC-CS492) by Sai Iyer in CSE-02 3-4: Computer Architecture Lab (PCC-CS492) by Sai Iyer in CSE-02 4-5: Computer Architecture Lab (PCC-CS492) by Sai Iyer in CSE-02
# Tue: 9-10: Design and Analysis ofAlgorithms (PCC-CS404) by Aarav Sharma in CSE-02 10-11: Design and Analysis ofAlgorithms (PCC-CS404) by Aarav Sharma in CSE-02 11-12: Design and Analysis ofAlgorithms (PCC-CS404) by Aarav Sharma in CSE-01 12-1: Discrete Mathematics (PCC-CS401) by Aditya Singh in CSE-01 2-3: Discrete Mathematics (PCC-CS401) by Aditya Singh in CSE-01 3-4: Discrete Mathematics (PCC-CS401) by Aditya Singh in CSE-01 4-5: Discrete Mathematics (PCC-CS401) by Aditya Singh in CSE-01
# Wed: 9-10: Environmental Sciences (MC-401) by Harshit Goyal in CSE-01 10-11: Formal Language & Automata Theory (PCC-CS403) by Neha Gupta in CSE-02 11-12: Formal Language & Automata Theory (PCC-CS403) by Neha Gupta in CSE-02 12-1: Formal Language & Automata Theory (PCC-CS403) by Neha Gupta in CSE-01 2-3: Free 3-4: Free 4-5: Free
# Thu: 9-10: Free 10-11: Free 11-12: Free 12-1: Free 2-3: Free 3-4: Free 4-5: Free
# Fri: 9-10: Free 10-11: Free 11-12: Free 12-1: Free 2-3: Free 3-4: Free 4-5: Free
#
# Routine for Section B:
# Mon: 9-10: Computer Architecture Lab (PCC-CS492) by Sai Iyer in CSE-02 10-11: Computer Architecture Lab (PCC-CS492) by Sai Iyer in CSE-02 11-12: Computer Architecture Lab (PCC-CS492) by Sai Iyer in CSE-02 12-1: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01 2-3: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01 3-4: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01 4-5: Computer Architecture Lab (PCC-CS492) by Meera Kulkarni in CSE-03
# Tue: 9-10: Design and Analysis ofAlgorithms (PCC-CS404) by Isha Verma in CSE-03 10-11: Design and Analysis ofAlgorithms (PCC-CS404) by Isha Verma in CSE-03 11-12: Design and Analysis ofAlgorithms (PCC-CS404) by Isha Verma in CSE-02 12-1: Discrete Mathematics (PCC-CS401) by Nikhil Arora in CSE-02 2-3: Discrete Mathematics (PCC-CS401) by Nikhil Arora in CSE-02 3-4: Discrete Mathematics (PCC-CS401) by Nikhil Arora in CSE-02 4-5: Discrete Mathematics (PCC-CS401) by Nikhil Arora in CSE-02
# Wed: 9-10: Formal Language & Automata Theory (PCC-CS403) by Neha Gupta in CSE-02 10-11: Environmental Sciences (MC-401) by Harshit Goyal in CSE-01 11-12: Formal Language & Automata Theory (PCC-CS403) by Aditya Singh in CSE-03 12-1: Formal Language & Automata Theory (PCC-CS403) by Aditya Singh in CSE-02 2-3: Free 3-4: Free 4-5: Free
# Thu: 9-10: Free 10-11: Free 11-12: Free 12-1: Free 2-3: Free 3-4: Free 4-5: Free
# Fri: 9-10: Free 10-11: Free 11-12: Free 12-1: Free 2-3: Free 3-4: Free 4-5: Free
#
# Routine for Section C:
# Mon: 9-10: Computer Architecture Lab (PCC-CS492) by Meera Kulkarni in CSE-03 10-11: Computer Architecture Lab (PCC-CS492) by Meera Kulkarni in CSE-03 11-12: Computer Architecture Lab (PCC-CS492) by Meera Kulkarni in CSE-03 12-1: Computer Architecture Lab (PCC-CS492) by Meera Kulkarni in CSE-03 2-3: Design and Analysis ofAlgorithms (PCC-CS404) by Aarav Sharma in CSE-03 3-4: Design and Analysis ofAlgorithms (PCC-CS404) by Aarav Sharma in CSE-03 4-5: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01
# Tue: 9-10: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01 10-11: Computer Architecture (PCC-CS402) by Rohan Mehta in CSE-01 11-12: Design and Analysis ofAlgorithms (PCC-CS404) by Rohan Mehta in CSE-03 12-1: Discrete Mathematics (PCC-CS401) by Harshit Goyal in CSE-03 2-3: Discrete Mathematics (PCC-CS401) by Harshit Goyal in CSE-03 3-4: Discrete Mathematics (PCC-CS401) by Harshit Goyal in CSE-03 4-5: Discrete Mathematics (PCC-CS401) by Harshit Goyal in CSE-03
# Wed: 9-10: Formal Language & Automata Theory (PCC-CS403) by Aditya Singh in CSE-03 10-11: Formal Language & Automata Theory (PCC-CS403) by Aditya Singh in CSE-03 11-12: Environmental Sciences (MC-401) by Harshit Goyal in CSE-01 12-1: Free 2-3: Formal Language & Automata Theory (PCC-CS403) by Neha Gupta in CSE-01 3-4: Free 4-5: Free
# Thu: 9-10: Free 10-11: Free 11-12: Free 12-1: Free 2-3: Free 3-4: Free 4-5: Free
# Fri: 9-10: Free 10-11: Free 11-12: Free 12-1: Free 2-3: Free 3-4: Free 4-5: Free

# %%
import pandas as pd
import re
import random
import os

class SmartRoutineGenerator:
    DAYS = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
    TIME_SLOTS = ['9-10', '10-11', '11-12', '12-1', '2-3', '3-4', '4-5']
    
    def _init_(self):
        self.faculty_df = None
        self.room_df = None
        self.student_df = None
    
    def load_data(self, faculty_file, room_file, student_file):
        try:
            self.faculty_df = pd.read_csv(faculty_file, low_memory=True)
            self.room_df = pd.read_csv(room_file, low_memory=True)
            self.student_df = pd.read_csv(student_file, low_memory=True)
            
            self.faculty_df.columns = self.faculty_df.columns.str.strip()
            self.room_df.columns = self.room_df.columns.str.strip()
            self.student_df.columns = self.student_df.columns.str.strip()
            
            if self.faculty_df.empty or self.room_df.empty or self.student_df.empty:
                print("[ERROR] One or more dataframes are empty")
                return False
            return True
        except Exception as e:
            print(f"[ERROR] Failed to load data: {e}")
            return False
    
    def parse_contact_hours(self, contact_hour_string):
        if not contact_hour_string or contact_hour_string == "Unknown":
            return {'L': 0, 'T': 0, 'P': 0}
        contact_hour_string = contact_hour_string.replace('/week', '')
        hours = {'L': 0, 'T': 0, 'P': 0}
        matches = re.findall(r'(\d+)([LTP])', contact_hour_string)
        for count, type_char in matches:
            hours[type_char] = int(count)
        return hours
    
    def parse_unavailable_slots(self, unavailable_str):
        if pd.isna(unavailable_str) or unavailable_str == "":
            return []
        slots = []
        for slot in str(unavailable_str).split('|'):
            slot = slot.strip()
            if ':' in slot:
                parts = slot.split()
                if len(parts) >= 2:
                    day = parts[0]
                    time_range = parts[1]
                    if '10:00-12:00' in time_range:
                        slots.extend([(day, '10-11'), (day, '11-12')])
                    elif '14:00-16:00' in time_range:
                        slots.extend([(day, '2-3'), (day, '3-4')])
                    elif '09:00-10:00' in time_range:
                        slots.append((day, '9-10'))
                    elif '11:00-13:00' in time_range:
                        slots.extend([(day, '11-12'), (day, '12-1')])
                    elif '13:00-15:00' in time_range:
                        slots.extend([(day, '12-1'), (day, '2-3')])
        return slots
    
    def get_suitable_rooms(self, subject_name, department, student_count):
        room_type = 'Lab' if 'Lab' in subject_name or 'lab' in subject_name else 'Classroom'
        suitable_rooms = self.room_df[
            (self.room_df['room_type'].str.contains(room_type, case=False, na=False)) &
            (self.room_df['capacity'] >= student_count) &
            ((self.room_df['department'].str.upper() == department.upper()) | 
             (self.room_df['department'].str.upper() == 'GENERAL'))
        ]['room_name'].tolist()
        if not suitable_rooms:
            suitable_rooms = self.room_df[self.room_df['capacity'] >= student_count]['room_name'].tolist()
        if not suitable_rooms:
            suitable_rooms = self.room_df['room_name'].tolist()[:3]
        return suitable_rooms or ['DefaultRoom']
    
    def get_qualified_faculty(self, subject_name, department, year):
        qualified_faculty = []
        for _, faculty in self.faculty_df.iterrows():
            faculty_subjects = str(faculty.get('subjects', '')).lower()
            faculty_name = faculty.get('name', '')
            subject_keywords = []
            if 'biology' in subject_name.lower():
                subject_keywords.extend(['biology', 'bio'])
            elif 'computer architecture' in subject_name.lower():
                subject_keywords.extend(['computer architecture', 'architecture', 'computer'])
            elif 'lab' in subject_name.lower():
                subject_keywords.extend(['lab', 'laboratory', 'practical'])
            elif 'algorithm' in subject_name.lower():
                subject_keywords.extend(['algorithm', 'algorithms'])
            elif 'discrete mathematics' in subject_name.lower():
                subject_keywords.extend(['discrete', 'mathematics', 'math'])
            elif 'environmental' in subject_name.lower():
                subject_keywords.extend(['environmental', 'environment'])
            elif 'formal language' in subject_name.lower() or 'automata' in subject_name.lower():
                subject_keywords.extend(['formal', 'language', 'automata', 'theory'])
            else:
                subject_keywords = [word.lower().strip('()[]') for word in subject_name.split() 
                                  if len(word.strip('()[]')) > 2]
            
            if any(keyword in faculty_subjects for keyword in subject_keywords) or 'general' in faculty_subjects or 'all' in faculty_subjects:
                faculty_dept = str(faculty.get('department', '')).upper()
                faculty_year = str(faculty.get('year_to_teach', ''))
                if (faculty_dept in [department.upper(), 'GENERAL', 'ALL'] and 
                    (str(year) in faculty_year or faculty_year.upper() == 'ALL' or faculty_year == '')):
                    qualified_faculty.append({
                        'name': faculty_name,
                        'max_load_hours': faculty.get('max_load_hours', 20),
                        'unavailable_slots': self.parse_unavailable_slots(faculty.get('unavailable_slots', ''))
                    })
        
        return qualified_faculty or [{
            'name': faculty['name'],
            'max_load_hours': 20,
            'unavailable_slots': []
        } for _, faculty in self.faculty_df.head(2).iterrows()]
    
    def is_faculty_available(self, faculty_name, day, time_slot, faculty_schedule):
        return faculty_schedule.get(faculty_name, {}).get(day, {}).get(time_slot) is None
    
    def is_room_available(self, room_name, day, time_slot, room_schedule):
        return room_schedule.get(room_name, {}).get(day, {}).get(time_slot) is None
    
    def assign_class(self, subject_name, contact_hours, faculty_list, rooms, 
                    section, day, time_slot, faculty_schedule, room_schedule, 
                    faculty_workload, section_schedule):
        available_faculty = [
            f for f in faculty_list
            if self.is_faculty_available(f['name'], day, time_slot, faculty_schedule) and
            (day, time_slot) not in f['unavailable_slots'] and
            faculty_workload.get(f['name'], 0) < f['max_load_hours']
        ]
        if not available_faculty:
            return False
        
        chosen_faculty = random.choice(available_faculty)
        faculty_name = chosen_faculty['name']
        available_rooms = [room for room in rooms if self.is_room_available(room, day, time_slot, room_schedule)]
        if not available_rooms:
            return False
        
        chosen_room = random.choice(available_rooms)
        
        faculty_schedule.setdefault(faculty_name, {}).setdefault(day, {})[time_slot] = f"{subject_name} - {section}"
        room_schedule.setdefault(chosen_room, {}).setdefault(day, {})[time_slot] = f"{subject_name} - {section}"
        faculty_workload[faculty_name] = faculty_workload.get(faculty_name, 0) + 1
        section_schedule.setdefault(section, {}).setdefault(day, {})[time_slot] = {
            'subject': subject_name,
            'faculty': faculty_name,
            'room': chosen_room
        }
        return True
    
    def distribute_classes(self, subject_requirements, sections, faculty_schedule, 
                         room_schedule, faculty_workload, section_schedules):
        assignments_made = {f"{subject_name}-{section}": 0 
                          for subject_name in subject_requirements for section in sections}
        
        # Assign classes to meet contact hours, prioritizing early days
        for subject_name, (contact_hours, faculty_list, rooms) in subject_requirements.items():
            total_hours = sum(contact_hours.values())
            for section in sections:
                hours_assigned = 0
                for day in self.DAYS:  # Prioritize Mon-Wed
                    if hours_assigned >= total_hours:
                        break
                    for time_slot in [t for t in self.TIME_SLOTS if t != "12-1"]:
                        if section_schedules[section][day].get(time_slot):
                            continue
                        if self.assign_class(subject_name, contact_hours, faculty_list, rooms, 
                                          section, day, time_slot, faculty_schedule, 
                                          room_schedule, faculty_workload, section_schedules):
                            assignments_made[f"{subject_name}-{section}"] += 1
                            hours_assigned += 1
                            if hours_assigned >= total_hours:
                                break
        return section_schedules
    
    def format_routine_output_table(self, section_schedules, sem):
        output = []
        for section in sorted(section_schedules.keys()):
            output.append(f"\n{'='*100}")
            output.append(f"ROUTINE FOR SECTION {section} - CSE {sem}th Semester")
            output.append(f"{'='*100}")
            output.append(f"{'Time':<8}│{'Monday':<20}│{'Tuesday':<20}│{'Wednesday':<20}│{'Thursday':<20}│{'Friday':<20}")
            output.append("─" * 8 + "┼" + "─" * 20 + "┼" + "─" * 20 + "┼" + "─" * 20 + "┼" + "─" * 20 + "┼" + "─" * 20)
            
            for time_slot in self.TIME_SLOTS:
                if time_slot == "12-1":
                    output.append(f"{'12-1':<8}│{'BREAK':<20}│{'BREAK':<20}│{'BREAK':<20}│{'BREAK':<20}│{'BREAK':<20}")
                else:
                    lines = ["", "", ""]
                    for day in self.DAYS:
                        slot_info = section_schedules[section][day].get(time_slot)
                        if slot_info:
                            subject = slot_info['subject'][:17] + "..." if len(slot_info['subject']) > 17 else slot_info['subject']
                            faculty = slot_info['faculty'][:17] + "..." if len(slot_info['faculty']) > 17 else slot_info['faculty'] 
                            room = slot_info['room'][:17] + "..." if len(slot_info['room']) > 17 else slot_info['room']
                            lines[0] += f"│{subject:<20}"
                            lines[1] += f"│{faculty:<20}"
                            lines[2] += f"│{room:<20}"
                        else:
                            lines[0] += f"│{'FREE':<20}"
                            lines[1] += f"│{'':<20}"
                            lines[2] += f"│{'':<20}"
                    
                    output.append(f"{time_slot:<8}{lines[0]}")
                    output.append(f"{'':<8}{lines[1]}")
                    output.append(f"{'':<8}{lines[2]}")
                output.append("─" * 8 + "┼" + "─" * 20 + "┼" + "─" * 20 + "┼" + "─" * 20 + "┼" + "─" * 20 + "┼" + "─" * 20)
            
            output.append("")
        
        output.append(f"\n{'='*100}")
        output.append("TIMETABLE SUMMARY")
        output.append(f"{'='*100}")
        
        faculty_workload = {}
        for section in sorted(section_schedules.keys()):
            total_classes = 0
            subject_count = {}
            for day in self.DAYS:
                for time_slot in self.TIME_SLOTS:
                    if time_slot == "12-1":
                        continue
                    slot_info = section_schedules[section][day].get(time_slot)
                    if slot_info:
                        total_classes += 1
                        subject = slot_info['subject']
                        faculty = slot_info['faculty']
                        subject_count[subject] = subject_count.get(subject, 0) + 1
                        faculty_workload[faculty] = faculty_workload.get(faculty, 0) + 1
            
            output.append(f"\nSection {section}: {total_classes} classes scheduled")
            for subject, count in sorted(subject_count.items()):
                output.append(f"  • {subject}: {count} hours/week")
        
        output.append(f"\n{'-'*50}")
        output.append("FACULTY WORKLOAD DISTRIBUTION")
        output.append(f"{'-'*50}")
        for faculty, hours in sorted(faculty_workload.items()):
            output.append(f"{faculty:<25}: {hours} hours/week")
        
        return "\n".join(output)
    
    def generate_routine(self, dept, sem, contact_hours_dict):
        try:
            year = int(sem)
            sections_data = self.student_df[
                (self.student_df['department'] == dept) & 
                (self.student_df['year'] == year)
            ]
            
            if sections_data.empty:
                print(f"[ERROR] No sections found for {dept} Year {year}")
                return f"No sections found for {dept} Year {year}"
            
            sections = sections_data['section'].tolist()
            faculty_schedule = {}
            room_schedule = {}
            faculty_workload = {}
            section_schedules = {section: {day: {} for day in self.DAYS} for section in sections}
            
            student_count = sections_data.iloc[0].get('total_number_of_students', 
                                                   sections_data.iloc[0].get('total_students', 50))
            
            subject_requirements = {}
            for subject_name, contact_hours_str in contact_hours_dict.items():
                if contact_hours_str == "Unknown":
                    continue
                contact_hours = self.parse_contact_hours(contact_hours_str)
                qualified_faculty = self.get_qualified_faculty(subject_name, dept, year)
                suitable_rooms = self.get_suitable_rooms(subject_name, dept, student_count)
                subject_requirements[subject_name] = (contact_hours, qualified_faculty, suitable_rooms)
            
            if not subject_requirements:
                print(f"[ERROR] No valid subjects to schedule")
                return "No valid subjects to schedule"
            
            section_schedules = self.distribute_classes(subject_requirements, sections, 
                                                     faculty_schedule, room_schedule, 
                                                     faculty_workload, section_schedules)
            
            return self.format_routine_output_table(section_schedules, sem)
        except Exception as e:
            print(f"[ERROR] Error in generate_routine: {e}")
            return f"Failed to generate routine: {e}"

def generate_smart_routine_from_variables(dept, sem, contact_hours_dict=None):
    print(f"[INFO] Generating routine for dept={dept}, sem={sem}")
    if contact_hours_dict is None:
        contact_hours_dict = {
            "Biology (BSC)": "3L",
            "Computer Architecture (PCC-CS402)": "3L+1T",
            "Computer Architecture Lab (PCC-CS492)": "3P",
            "Design and Analysis of Algorithms (PCC-CS404)": "3L+1T",
            "Discrete Mathematics (PCC-CS401)": "3L",
            "Environmental Sciences (MC-401)": "1L",
            "Formal Language & Automata Theory (PCC-CS403)": "3L"
        }
    
    generator = SmartRoutineGenerator()
    dataset_dir = '/kaggle/input/college-data/'
    faculty_file = dataset_dir + 'faculty_assignments.csv'
    room_file = dataset_dir + 'room_assignments.csv'
    student_file = dataset_dir + 'student_sections.csv'
    
    if not os.path.exists(faculty_file):
        print(f"[ERROR] Faculty file not found: {faculty_file}")
        return "Faculty file not found"
    if not os.path.exists(room_file):
        print(f"[ERROR] Room file not found: {room_file}")
        return "Room file not found"
    if not os.path.exists(student_file):
        print(f"[ERROR] Student file not found: {student_file}")
        return "Student file not found"
    
    if not generator.load_data(faculty_file, room_file, student_file):
        return "Failed to load data files"
    
    return generator.generate_routine(dept, sem, contact_hours_dict)

if __name__ == "__main__":
    dept = "CSE"
    sem = "4"
    routine = generate_smart_routine_from_variables(dept, sem)
    print(routine)
# Out:
# [INFO] Generating routine for dept=CSE, sem=4
#
# ====================================================================================================
# ROUTINE FOR SECTION A - CSE 4th Semester
# ====================================================================================================
# Time    │Monday              │Tuesday             │Wednesday           │Thursday            │Friday
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 9-10    │Biology (BSC)       │Computer Architec...│Computer Architec...│Formal Language &...│FREE
#         │Aarav Sharma        │Rohan Mehta         │Rohan Mehta         │Aditya Singh        │
#         │CSE-03              │ECE-04              │ECE-14              │CSE-01              │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 10-11   │Biology (BSC)       │Design and Analys...│Computer Architec...│Formal Language &...│FREE
#         │Aarav Sharma        │Aarav Sharma        │Rohan Mehta         │Aditya Singh        │
#         │IT-06               │CSE-05              │CSE-10              │ECE-10              │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 11-12   │Biology (BSC)       │Design and Analys...│Discrete Mathemat...│FREE                │FREE
#         │Isha Verma          │Isha Verma          │Harshit Goyal       │                    │
#         │CSE-09              │ECE-11              │CSE-06              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 12-1    │BREAK               │BREAK               │BREAK               │BREAK               │BREAK
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 2-3     │Computer Architec...│Design and Analys...│Discrete Mathemat...│FREE                │FREE
#         │Rohan Mehta         │Isha Verma          │Nikhil Arora        │                    │
#         │IT-03               │IT-07               │ECE-06              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 3-4     │Computer Architec...│Design and Analys...│Environmental Sci...│FREE                │FREE
#         │Rohan Mehta         │Aarav Sharma        │Harshit Goyal       │                    │
#         │ECE-08              │CSE-03              │IT-12               │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 4-5     │Computer Architec...│Discrete Mathemat...│Formal Language &...│FREE                │FREE
#         │Rohan Mehta         │Harshit Goyal       │Aditya Singh        │                    │
#         │ECE-08              │IT-07               │CSE-08              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
#
#
# ====================================================================================================
# ROUTINE FOR SECTION B - CSE 4th Semester
# ====================================================================================================
# Time    │Monday              │Tuesday             │Wednesday           │Thursday            │Friday
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 9-10    │Biology (BSC)       │Design and Analys...│Discrete Mathemat...│FREE                │FREE
#         │Isha Verma          │Isha Verma          │Aditya Singh        │                    │
#         │CSE-04              │IT-05               │CSE-08              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 10-11   │Biology (BSC)       │Computer Architec...│Discrete Mathemat...│FREE                │FREE
#         │Isha Verma          │Rohan Mehta         │Nikhil Arora        │                    │
#         │CSE-13              │IT-09               │CSE-03              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 11-12   │Biology (BSC)       │Computer Architec...│Formal Language &...│FREE                │FREE
#         │Aarav Sharma        │Rohan Mehta         │Neha Gupta          │                    │
#         │ECE-14              │CSE-07              │IT-07               │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 12-1    │BREAK               │BREAK               │BREAK               │BREAK               │BREAK
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 2-3     │Design and Analys...│Computer Architec...│Environmental Sci...│FREE                │FREE
#         │Isha Verma          │Rohan Mehta         │Harshit Goyal       │                    │
#         │ECE-05              │ECE-11              │CSE-01              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 3-4     │Design and Analys...│Computer Architec...│Formal Language &...│FREE                │FREE
#         │Aarav Sharma        │Rohan Mehta         │Neha Gupta          │                    │
#         │IT-03               │IT-09               │CSE-01              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 4-5     │Design and Analys...│Discrete Mathemat...│Formal Language &...│FREE                │FREE
#         │Aarav Sharma        │Aditya Singh        │Neha Gupta          │                    │
#         │IT-05               │ECE-01              │IT-09               │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
#
#
# ====================================================================================================
# ROUTINE FOR SECTION C - CSE 4th Semester
# ====================================================================================================
# Time    │Monday              │Tuesday             │Wednesday           │Thursday            │Friday
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 9-10    │Computer Architec...│Design and Analys...│Discrete Mathemat...│FREE                │FREE
#         │Rohan Mehta         │Aarav Sharma        │Nikhil Arora        │                    │
#         │CSE-09              │IT-06               │IT-11               │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 10-11   │Computer Architec...│Design and Analys...│Discrete Mathemat...│FREE                │FREE
#         │Rohan Mehta         │Isha Verma          │Harshit Goyal       │                    │
#         │IT-10               │ECE-07              │ECE-09              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 11-12   │Computer Architec...│Design and Analys...│Formal Language &...│FREE                │FREE
#         │Rohan Mehta         │Aarav Sharma        │Aditya Singh        │                    │
#         │ECE-08              │CSE-11              │ECE-13              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 12-1    │BREAK               │BREAK               │BREAK               │BREAK               │BREAK
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 2-3     │Biology (BSC)       │Design and Analys...│Formal Language &...│FREE                │FREE
#         │Aarav Sharma        │Aarav Sharma        │Neha Gupta          │                    │
#         │CSE-14              │ECE-07              │CSE-06              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 3-4     │Biology (BSC)       │Discrete Mathemat...│Formal Language &...│FREE                │FREE
#         │Isha Verma          │Nikhil Arora        │Aditya Singh        │                    │
#         │IT-07               │ECE-09              │ECE-08              │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
# 4-5     │Biology (BSC)       │Computer Architec...│Environmental Sci...│FREE                │FREE
#         │Isha Verma          │Rohan Mehta         │Harshit Goyal       │                    │
#         │IT-07               │CSE-11              │IT-01               │                    │
# ────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────┼────────────────────
#
#
# ====================================================================================================
# TIMETABLE SUMMARY
# ====================================================================================================
#
# Section A: 20 classes scheduled
#   • Biology (BSC): 3 hours/week
#   • Computer Architecture (PCC-CS402): 4 hours/week
#   • Computer Architecture Lab (PCC-CS492): 2 hours/week
#   • Design and Analysis of Algorithms (PCC-CS404): 4 hours/week
#   • Discrete Mathematics (PCC-CS401): 3 hours/week
#   • Environmental Sciences (MC-401): 1 hours/week
#   • Formal Language & Automata Theory (PCC-CS403): 3 hours/week
#
# Section B: 18 classes scheduled
#   • Biology (BSC): 3 hours/week
#   • Computer Architecture (PCC-CS402): 4 hours/week
#   • Design and Analysis of Algorithms (PCC-CS404): 4 hours/week
#   • Discrete Mathematics (PCC-CS401): 3 hours/week
#   • Environmental Sciences (MC-401): 1 hours/week
#   • Formal Language & Automata Theory (PCC-CS403): 3 hours/week
#
# Section C: 18 classes scheduled
#   • Biology (BSC): 3 hours/week
#   • Computer Architecture (PCC-CS402): 4 hours/week
#   • Design and Analysis of Algorithms (PCC-CS404): 4 hours/week
#   • Discrete Mathematics (PCC-CS401): 3 hours/week
#   • Environmental Sciences (MC-401): 1 hours/week
#   • Formal Language & Automata Theory (PCC-CS403): 3 hours/week
#
# --------------------------------------------------
# FACULTY WORKLOAD DISTRIBUTION
# --------------------------------------------------
# Aarav Sharma             : 11 hours/week
# Aditya Singh             : 7 hours/week
# Harshit Goyal            : 6 hours/week
# Isha Verma               : 10 hours/week
# Neha Gupta               : 4 hours/week
# Nikhil Arora             : 4 hours/week
# Rohan Mehta              : 14 hours/week
